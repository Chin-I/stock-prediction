# %%
# This is a clean version of Part 1 and Part 2
# Part 1 is dense layer only random sample network
# Part 2 is LSTM with multiple input features

# %%
# Model 1, One Feature, Random window, Dense only but with multiple layers
import sys
import numpy as np
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline
from random import randint
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, Convolution1D, Convolution2D
from keras.regularizers import l2, activity_l2
from keras.layers import Merge, LSTM, Dense 
from copy import deepcopy
np.random.seed(7) # fix random seed to ensure the results are reproducible

# reference from : http://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
# dataframe = pandas.read_csv('Yahoo+Nasdaq+SP500+DJ30-20100101-20161231.csv', usecols=['YHOO-Open', 'YHOO-High', 'YHOO-Low', 'YHOO-Close', 'YHOO-Adj_Close', 'YHOO-Volume'])
dataframe = pandas.read_csv('YHOO_2007-2016.csv', usecols=['YHOO-High'])
dataset = dataframe.values
# reverse the dataset by row, oldest date first
dataset = np.flip(dataset, 0)
dataset.astype('float32')

# plot the dataset
# plt.title('Yahoo HighPrice - Date')
# plt.plot(dataset)
# plt.show()

# normalization
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split training and test sets
train_size = int(len(dataset) * 0.9)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:, :]
# convert an array of values into a dataset matrix
def create_random_dataset(dataset, look_back, iteration_time):
    dataX, dataY = [], []
    for i in range(iteration_time):
        start = randint(0, len(dataset)-look_back-1) # randint(a,b), a <= x <= b
        a = dataset[start:(start+look_back), :]
        dataX.append(a)
        dataY.append(dataset[start+look_back, 0])
    return np.array(dataX), np.array(dataY)

def create_ordered_dataset(dataset, look_back):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = deepcopy(dataset[i:(i+look_back), :])
        dataX.append(a)
        dataY.append(dataset[i+look_back, 0])
    return np.array(dataX), np.array(dataY)

# reshape training and test set into X = t, Y = t + 1
look_back = 10
iteration_time = 5000
trainX, trainY = create_random_dataset(train, look_back, iteration_time)
testX, testY = create_random_dataset(test, look_back, 5)
orderedX, orderedY = create_ordered_dataset(dataset, look_back) # this is used for trend evaluation



#before Transform
print ("Before Transform")
print trainX.shape,testX.shape,orderedX.shape


# transform data into two dim input. Since it's already 2d, this part is useless. 
# If more features are used, we need this part to increase the dimension
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1]))
orderedX = np.reshape(orderedX, (orderedX.shape[0], orderedX.shape[1]))
# print(trainX[0:5])
# print(trainY.shape)

print ("After Transform")
print trainX.shape,testX.shape,orderedX.shape

print "trainX,trainY"
print trainX.shape,trainY.shape

# # create training network
# # Reference: Which optimizer to use
# # http://sebastianruder.com/optimizing-gradient-descent/index.html #rmsprop
batchSize = 2
epoch = 1
print("Begin")
print "inputshape"
print (look_back,)
model = Sequential()
# model.add(Dense(25, input_shape=(look_back,)))
model.add(Dense(25, input_dim=look_back))
model.add(Dense(10))
model.add(Dense(1))
model.compile(optimizer='rmsprop',loss='mse') # can try optimizer = 'adam'

history = model.fit(trainX, trainY, validation_split=0.05, batch_size=batchSize, nb_epoch=epoch, initial_epoch=0, verbose = 1)
print("-------Finish-------")

# Evaluation on MSE
    # With current parameter
    # MSE on trainX: 0.429521106769, MSE on testX: 0.610605459544
    # Graph of training and test mse, here training and test data are all in trainX
plt.axis((0, epoch, 0, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
    # MSE on trainX and testX   
training_loss = model.evaluate(trainX, trainY, batch_size=batchSize, verbose = 1)
print("\nMSE on trainX: {}".format(training_loss))
test_loss = model.evaluate(testX, testY, batch_size=batchSize, verbose = 1)
print("\nMSE on testX: {}".format(test_loss))
cv = (np.sqrt(test_loss) / np.mean(testY)) * 100
print("Coefficient of Variation: ", cv, "%")

# Evaluation on Trend
orderedYHat_DENSE = model.predict(orderedX, batch_size = batchSize, verbose = 0)
# The YHat has one day delay compared with Y, that's the reason for previous bad performance
def evaluateY(Y, YHat):
    total = len(Y)
    count = 0
    for i in range(1, total-1):
        if (YHat[i] - YHat[i-1]) * (Y[i] - Y[i-1]) > 0:
            count += 1
    print("Trend prediction performance: {}%".format(count * 100.0 / total))
print('Overall:')
evaluateY(orderedY, orderedYHat_DENSE)    
print('Test Set Only:')
evaluateY(orderedY[train_size:], orderedYHat_DENSE[train_size:])  

plt.figure(figsize=(40,20))
plt.plot(orderedY)
plt.plot(orderedYHat_DENSE[:], c = 'r')
plt.show()

# predictions
# trainPredict = model.predict(trainX)
# testPredict = model.predict(testX)

# denormalization
# trainPredict = scaler.inverse_transform(trainPredict)
# trainY = scaler.inverse_transform(trainY)
# testPredict = scaler.inverse_transform(testPredict)
# testY = scaler.inverse_transform(testY)
# Out:
# Before Transform
# (5000, 10, 1) (5, 10, 1) (2508, 10, 1)
# After Transform
# (5000, 10) (5, 10) (2508, 10)
# trainX,trainY
# (5000, 10) (5000,)
# Begin
# inputshape
# (10,)
# Train on 4750 samples, validate on 250 samples
# Epoch 1/1
# 4750/4750 [==============================] - 7s - loss: 7.0289e-04 - val_loss: 2.7390e-04
# -------Finish-------
# 4960/5000 [============================>.] - ETA: 0s
# MSE on trainX: 0.000255308883033
# 2/5 [===========>..................] - ETA: 0s
# MSE on testX: 0.000100851453317
# ('Coefficient of Variation: ', 1.4367337257038804, '%')
# Overall:
# Trend prediction performance: 50.7177033493%
# Test Set Only:
# Trend prediction performance: 44.2148760331%

# %%
print(len(orderedX), len(orderedYHat_DENSE), len(orderedY))
print(len(dataset))
plt.figure(figsize=(40,20))
plt.plot(orderedY)
plt.plot(orderedYHat_DENSE[:], c = 'r')
plt.show()
# Out:
# (2498, 2498, 2498)
# 2518

# %%
# Model 2, LSTM with multiple features
# LSTM tuning
import sys
import numpy as np
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline
from random import randint
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, Convolution1D, Convolution2D
from keras.layers import Merge, LSTM, Dense 
np.random.seed(7) # fix random seed to ensure the results are reproducible
from copy import deepcopy

# reference from : http://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
# dataframe = pandas.read_csv('Yahoo+Nasdaq+SP500+DJ30-20100101-20161231.csv', usecols=['YHOO-Open', 'YHOO-High', 'YHOO-Low', 'YHOO-Close', 'YHOO-Adj_Close', 'YHOO-Volume'])
f = ['YHOO-Open', 'YHOO-High', 'YHOO-Low', 'YHOO-Close', 'YHOO-Adj_Close', 'YHOO-Volume']
dataframe = pandas.read_csv('YHOO_2007-2016.csv', usecols= f)
dataset = dataframe.values
# reverse the dataset by row, oldest date first
dataset = np.flip(dataset, 0) 
dataset.astype('float32')

# plot the dataset
# plt.title('Yahoo HighPrice - Date')
# plt.plot(dataset)
# plt.show()

# normalization
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split training and test sets
train_size = int(len(dataset) * 0.9)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:, :]

# convert an array of values into a dataset matrix
def create_ordered_dataset(dataset, look_back = 1):
    # dataset is in shape of (1762, 6)   
    # weights for the 6 input features 'YHOO-Open', 'YHOO-High', 'YHOO-Low', 'YHOO-Close', 'YHOO-Adj_Close', 'YHOO-Volume'
#     w = [0.01, 1, 0.01, 0.01, 0.01, 5*10e-10] 
    w = [1, 1, 1, 1, 1, 1]
    dataX= []
    dataY = []
    for i in range(len(dataset) - look_back):
        # A shallow copy might give me issue on weights     
        a = deepcopy(dataset[i:(i+look_back), :])   # shape of (20, 6) input length = 20, input dim = 6
        for m in range(len(a)):
            for n in range(len(a[m])):
                a[m][n] = a[m][n] * w[n]
        dataX.append(a)
        dataY.append(dataset[i+look_back][1]) # pick the next day's tuple, get Yahoo-High
    return np.array(dataX), np.array(dataY)

# reshape training and test set into X = t, Y = t + 1
# data dimension should be [dim1 - samples, dim2 - window size, dim3 - features]
look_back = 20 #18
batchSize = 1
epoch = 15
trainX, trainY = create_ordered_dataset(train, look_back)
testX, testY = create_ordered_dataset(test, look_back)
orderedX, orderedY = create_ordered_dataset(dataset, look_back)
# print('trainX.shape:')
# print(trainX[0][6])
# print('trainY.shape:')
# print(trainY.shape)
    
# create training network
# Reference: Which optimizer to use
# http://sebastianruder.com/optimizing-gradient-descent/index.html#rmsprop
model = Sequential()
model.add(LSTM(20, input_dim = len(f), input_length = look_back, return_sequences=False))
model.add(Dense(10))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer = 'rmsprop')
history = model.fit(trainX, trainY, batch_size=batchSize, nb_epoch=epoch, verbose = 2, validation_split=0.1)
# Reference for parameters: https://keras.io/models/sequential/

# Evaluation on MSE
    # With current parameter
    # MSE on trainX: 0.429521106769, MSE on testX: 0.610605459544
    # Graph of training and test mse, here training and test data are all in trainX
plt.axis((0, epoch, 0, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
    # MSE on trainX and testX   
training_loss = model.evaluate(trainX, trainY, batch_size=batchSize, verbose = 1)
print("\nMSE on trainX: {}".format(training_loss))
test_loss = model.evaluate(testX, testY, batch_size=batchSize, verbose = 1)
print("\nMSE on testX: {}".format(test_loss))
cv = (np.sqrt(test_loss) / np.mean(testY)) * 100
print("Coefficient of Variation: ", cv, "%")

# Evaluation on Trend
orderedYHat_LSTM = model.predict(orderedX, batch_size = batchSize, verbose = 0);
# The YHat has one day delay compared with Y, that's the reason for previous bad performance
def evaluateY(Y, YHat):
    total = len(Y)
    count = 0
    for i in range(1, total-1):
        if (YHat[i] - YHat[i-1]) * (Y[i] - Y[i-1]) > 0:
            count += 1
    print("Trend prediction performance: {}%".format(count * 100.0 / total))
print('Overall:')
evaluateY(orderedY, orderedYHat_LSTM)    
print('Test Set Only:')
evaluateY(orderedY[train_size:], orderedYHat_LSTM[train_size:])  

plt.figure(figsize=(40,20))
plt.plot(orderedY)
plt.plot(orderedYHat_LSTM[1:], c = 'r')
plt.show()
# Out:
# Using TensorFlow backend.
# Train on 2021 samples, validate on 225 samples
# Epoch 1/15
# 189s - loss: 0.0029 - val_loss: 6.0129e-04
# Epoch 2/15
# 194s - loss: 3.7678e-04 - val_loss: 2.3221e-04
# Epoch 3/15
# 197s - loss: 2.8705e-04 - val_loss: 3.5171e-04
# Epoch 4/15
# 229s - loss: 2.6260e-04 - val_loss: 2.6168e-04
# Epoch 5/15
# 266s - loss: 2.4200e-04 - val_loss: 2.9673e-04
# Epoch 6/15
# 246s - loss: 2.4108e-04 - val_loss: 0.0016
# Epoch 7/15
# 231s - loss: 2.2128e-04 - val_loss: 1.8723e-04
# Epoch 8/15
# 202s - loss: 2.1652e-04 - val_loss: 2.0372e-04
# Epoch 9/15
# 223s - loss: 2.1218e-04 - val_loss: 7.7520e-04
# Epoch 10/15

# %%
print(len(dataset), len(orderedX), len(orderedYHat_LSTM))
# Out:
# (2518, 2498, 2498)

# %%
# Model 3, Cara's Convolutional NN with single feature
import sys
import numpy as np
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline
from random import randint
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, Convolution1D, Convolution2D
from keras.regularizers import l2, activity_l2
from keras.layers import Merge, LSTM, Dense 
from keras.layers import Flatten
from copy import deepcopy
np.random.seed(7) # fix random seed to ensure the results are reproducible

# reference from : http://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
# dataframe = pandas.read_csv('Yahoo+Nasdaq+SP500+DJ30-20100101-20161231.csv', usecols=['YHOO-Open', 'YHOO-High', 'YHOO-Low', 'YHOO-Close', 'YHOO-Adj_Close', 'YHOO-Volume'])
dataframe = pandas.read_csv('YHOO_2007-2016.csv', usecols=['YHOO-High'])
dataset = dataframe.values
# reverse the dataset by row, oldest date first
dataset = np.flip(dataset, 0) 
dataset.astype('float32')

# plot the dataset
# plt.title('Yahoo HighPrice - Date')
# plt.plot(dataset)
# plt.show()

# normalization
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split training and test sets
train_size = int(len(dataset) * 0.9)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:, :]
# convert an array of values into a dataset matrix
def create_random_dataset(dataset, look_back = 1, iteration_time = 1):
    dataX, dataY = [], []
    for i in range(iteration_time):
        start = randint(0, len(dataset)-look_back-1) # randint(a,b), a <= x <= b
        a = dataset[start:(start+look_back), :]
        dataX.append(a)
        dataY.append(dataset[start+look_back, 0])
    return np.array(dataX), np.array(dataY)

def create_ordered_dataset(dataset, look_back = 1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = deepcopy(dataset[i:(i+look_back), :])
        dataX.append(a)
        dataY.append(dataset[i+look_back, 0])
    return np.array(dataX), np.array(dataY)

# reshape training and test set into X = t, Y = t + 1
look_back = 20
iteration_time = 5000
trainX, trainY = create_random_dataset(train, look_back, iteration_time)
testX, testY = create_random_dataset(test, look_back, 6)
orderedX, orderedY = create_ordered_dataset(dataset, look_back) # this is used for trend evaluation

# transform data into two dim input. Since it's already 2d, this part is useless. 
# If more features are used, we need this part to increase the dimension
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))
orderedX = np.reshape(orderedX, (orderedX.shape[0], orderedX.shape[1], 1))
# print(trainX[0:5])
print(trainX.shape)

# # create training network
# # Reference: Which optimizer to use
# # http://sebastianruder.com/optimizing-gradient-descent/index.html #rmsprop
batchSize = 5
epoch = 1
print("Begin")
model = Sequential()
model.add(Convolution1D(24, 5, border_mode='valid', input_shape=(look_back, 1), activation='relu'))
model.add(Convolution1D(24, 5, activation='relu'))
model.add(Flatten())
# model.add(Dense(25, input_shape=(look_back,)))
model.add(Dense(10))
model.add(Dense(1))
model.compile(optimizer='rmsprop',loss='mse') # can try optimizer = 'adam'
history = model.fit(trainX, trainY, validation_split=0.05, batch_size=batchSize, nb_epoch=epoch, initial_epoch=0, verbose = 1)
print("Finish")

# Evaluation on MSE
    # With current parameter
    # MSE on trainX: 0.429521106769, MSE on testX: 0.610605459544
    # Graph of training and test mse, here training and test data are all in trainX
plt.axis((0, epoch, 0, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
    # MSE on trainX and testX   
training_loss = model.evaluate(trainX, trainY, batch_size=batchSize, verbose = 1)
print("\nMSE on trainX: {}".format(training_loss))
test_loss = model.evaluate(testX, testY, batch_size=batchSize, verbose = 1)
print("\nMSE on testX: {}".format(test_loss))
cv = (np.sqrt(test_loss) / np.mean(testY)) * 100
print("Coefficient of Variation: ", cv, "%")

# Evaluation on Trend
orderedYHat_CONV = model.predict(orderedX, batch_size = batchSize, verbose = 0);
# The YHat has one day delay compared with Y, that's the reason for previous bad performance
def evaluateY(Y, YHat):
    total = len(Y)
    count = 0
    for i in range(1, total-1):
        if (YHat[i] - YHat[i-1]) * (Y[i] - Y[i-1]) > 0:
            count += 1
    print("Trend prediction performance: {}%".format(count * 100.0 / total))
print('Overall:')
evaluateY(orderedY, orderedYHat_CONV)    
print('Test Set Only:')
evaluateY(orderedY[train_size:], orderedYHat_CONV[train_size:])  

plt.figure(figsize=(40,20))
plt.plot(orderedY)
plt.plot(orderedYHat_CONV[0:], c = 'r')
plt.show()

# predictions
# trainPredict = model.predict(trainX)
# testPredict = model.predict(testX)

# denormalization
# trainPredict = scaler.inverse_transform(trainPredict)
# trainY = scaler.inverse_transform(trainY)
# testPredict = scaler.inverse_transform(testPredict)
# testY = scaler.inverse_transform(testY)
# Out:
# (5000, 20, 1)
# Begin
# Train on 4750 samples, validate on 250 samples
# Epoch 1/1
# 4750/4750 [==============================] - 5s - loss: 0.0025 - val_loss: 0.0012
# Finish
# 5000/5000 [==============================] - 1s
#
# MSE on trainX: 0.00117379708015
# 5/6 [========================>.....] - ETA: 0s
# MSE on testX: 0.00159368350675
# ('Coefficient of Variation: ', 6.3549460920356866, '%')
# Overall:
# Trend prediction performance: 46.517213771%
# Test Set Only:
# Trend prediction performance: 43.9655172414%

# %%
# Part 4, Cara 2
# Conv tuning
import sys
import numpy as np
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline
from random import randint
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, Convolution1D, Convolution2D
from keras.layers import Merge, LSTM, Dense 
np.random.seed(7) # fix random seed to ensure the results are reproducible
from copy import deepcopy
from keras.layers import Flatten
# reference from : http://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/
# dataframe = pandas.read_csv('Yahoo+Nasdaq+SP500+DJ30-20100101-20161231.csv', usecols=['YHOO-Open', 'YHOO-High', 'YHOO-Low', 'YHOO-Close', 'YHOO-Adj_Close', 'YHOO-Volume'])
f = ['YHOO-Open', 'YHOO-High', 'YHOO-Low', 'YHOO-Close', 'YHOO-Adj_Close', 'YHOO-Volume']
dataframe = pandas.read_csv('YHOO_2007-2016.csv', usecols=f)
list(dataframe)
dataset = dataframe.values
#reverse the dataset by row, oldest date first
dataset = np.flip(dataset, 0) 
dataset.astype('float32')

# plot the dataset
# plt.title('Yahoo HighPrice - Date')
# plt.plot(dataset)
# plt.show()

# normalization
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split training and test sets
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:, :]

# convert an array of values into a dataset matrix
def create_ordered_dataset(dataset, look_back = 1):
    # dataset is in shape of (1762, 6)   
    # weights for the 6 input features 'YHOO-Open', 'YHOO-High', 'YHOO-Low', 'YHOO-Close', 'YHOO-Adj_Close', 'YHOO-Volume'
    w = [0.01, 1, 0.01, 0.01, 0.01, 5*10e-10] 
    dataX= []
    dataY = []
    for i in range(len(dataset) - look_back):
        # A shallow copy might give me issue on weights     
        a = deepcopy(dataset[i:(i+look_back), :])   # shape of (20, 6) input length = 20, input dim = 6
        for m in range(len(a)):
            for n in range(len(a[m])):
                a[m][n] = a[m][n] * 1 #w[n]
        dataX.append(a)
        dataY.append(dataset[i+look_back][1]) # pick the next day's tuple, get Yahoo-High
    return np.array(dataX), np.array(dataY)

# reshape training and test set into X = t, Y = t + 1
# data dimension should be [dim1 - samples, dim2 - window size, dim3 - features]
look_back = 20
batchSize = 20
epoch = 25
trainX, trainY = create_ordered_dataset(train, look_back)
testX, testY = create_ordered_dataset(test, look_back)
orderedX, orderedY = create_ordered_dataset(dataset, look_back)
print('trainX.shape:')
print(trainX.shape)
print('trainY.shape:')
print(trainY.shape)
    
# create training network
# Reference: Which optimizer to use
# http://sebastianruder.com/optimizing-gradient-descent/index.html#rmsprop
model = Sequential()
# model.add(LSTM(output_dim = len(f), input_dim = len(f), input_length = look_back, return_sequences=True))
# model.add(LSTM(output_dim = len(f), input_dim = len(f), input_length = look_back, return_sequences=False))
model.add(Convolution1D(25, 5, border_mode='valid', input_shape=(look_back, trainX.shape[2]), activation='tanh'))
model.add(Convolution1D(30, 5, activation='tanh'))
model.add(Flatten())
model.add(Dense(15))
model.add(Dense(10))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer = 'rmsprop')
history = model.fit(trainX, trainY, batch_size=batchSize, nb_epoch=epoch, verbose = 2, validation_split=0.1)
# Reference for parameters: https://keras.io/models/sequential/

# Evaluation on MSE
    # With current parameter
    # MSE on trainX: 0.429521106769, MSE on testX: 0.610605459544
    # Graph of training and test mse, here training and test data are all in trainX
plt.axis((0, epoch, 0, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
    # MSE on trainX and testX   
training_loss = model.evaluate(trainX, trainY, batch_size=batchSize, verbose = 1)
print("\nMSE on trainX: {}".format(training_loss))
test_loss = model.evaluate(testX, testY, batch_size=batchSize, verbose = 1)
print("\nMSE on testX: {}".format(test_loss))

# Evaluation on Trend
orderedYHat_CARA2 = model.predict(orderedX, batch_size = batchSize, verbose = 0);
# The YHat has one day delay compared with Y, that's the reason for previous bad performance
def evaluateY(Y, YHat):
    total = min(len(YHat), len(Y))
    count = 0
    for i in range(1, total-1):
        if (YHat[i] - YHat[i-1]) * (Y[i] - Y[i-1]) > 0:
            count += 1
    print("Trend prediction performance: {}%".format(count * 100.0 / total))
print('Overall:')
evaluateY(orderedY, orderedYHat_CARA2)    
print('Test Set Only:')
evaluateY(orderedY[train_size:], orderedYHat_CARA2[train_size:])  

plt.figure(figsize=(40,20))
plt.plot(orderedY)
plt.plot(orderedYHat_CARA2[:], c = 'r')
plt.show()
# Out:
# trainX.shape:
# (1742, 20, 6)
# trainY.shape:
# (1742,)
# Train on 1567 samples, validate on 175 samples
# Epoch 1/25
# 1s - loss: 0.0040 - val_loss: 0.0070
# Epoch 2/25
# 0s - loss: 0.0023 - val_loss: 0.0010
# Epoch 3/25
# 0s - loss: 0.0017 - val_loss: 9.0017e-04
# Epoch 4/25
# 0s - loss: 0.0014 - val_loss: 0.0062
# Epoch 5/25
# 0s - loss: 0.0013 - val_loss: 4.4969e-04
# Epoch 6/25
# 0s - loss: 0.0012 - val_loss: 0.0022
# Epoch 7/25
# 0s - loss: 0.0010 - val_loss: 9.2571e-04
# Epoch 8/25
# 0s - loss: 8.7746e-04 - val_loss: 0.0190
# Epoch 9/25
# 0s - loss: 6.9865e-04 - val_loss: 8.8065e-04
# Epoch 10/25
# 0s - loss: 8.1022e-04 - val_loss: 2.2075e-04
# Epoch 11/25
# 0s - loss: 6.7711e-04 - val_loss: 0.0052
# Epoch 12/25
# 0s - loss: 6.7747e-04 - val_loss: 0.0039
# Epoch 13/25
# 0s - loss: 5.9092e-04 - val_loss: 0.0146
# Epoch 14/25
# 0s - loss: 5.0954e-04 - val_loss: 0.0042
# Epoch 15/25
# 0s - loss: 5.8741e-04 - val_loss: 0.0014
# Epoch 16/25
# 0s - loss: 4.8497e-04 - val_loss: 9.4836e-04
# Epoch 17/25
# 0s - loss: 4.7033e-04 - val_loss: 2.7053e-04
# Epoch 18/25
# 0s - loss: 5.4060e-04 - val_loss: 4.0771e-04
# Epoch 19/25
# 0s - loss: 4.0495e-04 - val_loss: 2.8688e-04
# Epoch 20/25
# 0s - loss: 4.2997e-04 - val_loss: 0.0025
# Epoch 21/25
# 0s - loss: 4.8230e-04 - val_loss: 6.1672e-04
# Epoch 22/25
# 0s - loss: 4.3188e-04 - val_loss: 0.0010
# Epoch 23/25
# 0s - loss: 4.1595e-04 - val_loss: 0.0031
# Epoch 24/25
# 0s - loss: 4.6934e-04 - val_loss: 0.0057
# Epoch 25/25
# 0s - loss: 3.7860e-04 - val_loss: 0.0012
# 1340/1742 [======================>.......] - ETA: 0s
# MSE on trainX: 0.000338301427919
# 700/736 [===========================>..] - ETA: 0s
# MSE on testX: 0.00566024094318
# Overall:
# Trend prediction performance: 59.0872698159%
# Test Set Only:
# Trend prediction performance: 58.9673913043%

# %%
print(orderedYHat_CARA2.shape)
orderedYHat_LSTM = orderedYHat_LSTM.ravel()
orderedYHat_CONV = orderedYHat_CONV.ravel()
orderedYHat_DENSE = orderedYHat_DENSE.ravel()
orderedYHat_CARA2 = orderedYHat_CARA2.ravel()
lenLSTM, lenCONV, lenDENSE, lenCARA2 = orderedYHat_LSTM.shape[0], orderedYHat_CONV.shape[0], orderedYHat_DENSE.shape[0], orderedYHat_CARA2.shape[0]
print(lenLSTM, lenCONV, lenDENSE, lenCARA2)

YLen = min(lenLSTM, lenCONV, lenCARA2, lenDENSE, len(orderedY)) 
print(YLen)
# Out:
# (2498, 1)
# (2498, 2498, 2498, 2498)
# 2498

# %%
# # Ensemble using NN, Dense Layers

# print(YLen, lenLSTM, lenCONV, lenDENSE, lenCARA2)
# # orderedY = orderedY[-YLen-1 : -1]
# print(lenDENSE, lenLSTM, lenCONV, YLen)
# orderedYHat_LSTM = orderedYHat_LSTM[-YLen:]
# orderedYHat_CONV = orderedYHat_CONV[-YLen:]
# orderedYHat_DENSE = orderedYHat_DENSE[-YLen:]
# orderedYHat_CARA2 = orderedYHat_CARA2[-YLen:]

# orderedY = orderedY[-YLen:]

orderedYHat = []
for i in range(0, YLen):
    temp = [orderedYHat_LSTM[i], orderedYHat_CONV[i], orderedYHat_CARA2[i]]
    orderedYHat.append(temp)

train_size = int(YLen * 0.9)
test_size = YLen - train_size
trainX, trainY = orderedYHat[0:train_size], orderedY[0:train_size]
testX, testY = orderedYHat[train_size:], orderedY[train_size:]

model = Sequential()
model.add(Dense(3, input_dim = len(orderedYHat[0])))
model.add(Dense(2))
model.add(Dense(1))
model.compile(optimizer='rmsprop',loss='mse')
history = model.fit(trainX, trainY, batch_size = 1, nb_epoch = 30, initial_epoch = 0)
overallYHat = []
overallYHat = model.predict(orderedYHat, batch_size = 1, verbose = 0);
testYHat = model.predict(testX, batch_size = 2, verbose = 0);
# So far we are using all the data for training. We will want 70% for training and 30 for evaluateY 

def evaluateY(Y, YHat):
    total = len(YHat)
    count = 0
    for i in range(1, total-1):
        if (YHat[i] - YHat[i-1]) * (Y[i] - Y[i-1]) > 0:
            count += 1
    return (count * 100.0 / total)

print()
print('LSTM: {}'.format(evaluateY(orderedY, orderedYHat_LSTM)))
print('CONV: {}'.format(evaluateY(orderedY, orderedYHat_CONV)))
print('DENSE: {}'.format(evaluateY(orderedY, orderedYHat_DENSE)))
print('CARA2: {}'.format(evaluateY(orderedY, orderedYHat_CARA2)))

print()
print('Overall on everything: {}'.format(evaluateY(orderedY, overallYHat)))
print('Overall on test: {}'.format(evaluateY(testY, testYHat)))


plt.figure(figsize=(40,20))
plt.plot(orderedY)
plt.plot(orderedYHat_LSTM, c = 'r')
plt.show()

plt.figure(figsize=(40,20))
plt.plot(orderedY)
plt.plot(orderedYHat_CONV, c = 'r')
plt.show()

plt.figure(figsize=(40,20))
plt.plot(orderedY)
plt.plot(orderedYHat_DENSE, c = 'r')
plt.show()

plt.figure(figsize=(40,20))
plt.plot(orderedY)
plt.plot(overallYHat, c = 'r')
plt.show()
# Out:
# Epoch 1/30
# 2248/2248 [==============================] - 9s - loss: 0.0997
# Epoch 2/30
# 2248/2248 [==============================] - 9s - loss: 2.5124e-04
# Epoch 3/30
# 2248/2248 [==============================] - 9s - loss: 2.4656e-04
# Epoch 4/30
# 2248/2248 [==============================] - 9s - loss: 2.3630e-04
# Epoch 5/30
# 2248/2248 [==============================] - 8s - loss: 2.3357e-04
# Epoch 6/30
# 2248/2248 [==============================] - 9s - loss: 2.2879e-04
# Epoch 7/30
# 2248/2248 [==============================] - 9s - loss: 2.2224e-04
# Epoch 8/30
# 2248/2248 [==============================] - 11s - loss: 2.2271e-04
# Epoch 9/30
# 2248/2248 [==============================] - 13s - loss: 2.0921e-04
# Epoch 10/30
# 2248/2248 [==============================] - 8s - loss: 2.0752e-04
# Epoch 11/30
# 2248/2248 [==============================] - 9s - loss: 2.0387e-04
# Epoch 12/30
# 2248/2248 [==============================] - 9s - loss: 2.0336e-04
# Epoch 13/30
# 2248/2248 [==============================] - 11s - loss: 2.0104e-04
# Epoch 14/30
# 2248/2248 [==============================] - 10s - loss: 1.9958e-04
# Epoch 15/30
# 2248/2248 [==============================] - 10s - loss: 1.9605e-04
# Epoch 16/30
# 2248/2248 [==============================] - 10s - loss: 1.9928e-04
# Epoch 17/30
# 2248/2248 [==============================] - 11s - loss: 1.9472e-04
# Epoch 18/30
# 2248/2248 [==============================] - 9s - loss: 1.9382e-04
# Epoch 19/30
# 2248/2248 [==============================] - 9s - loss: 1.9112e-04
# Epoch 20/30
# 2248/2248 [==============================] - 9s - loss: 1.9270e-04
# Epoch 21/30
# 2248/2248 [==============================] - 9s - loss: 1.9380e-04
# Epoch 22/30
# 2248/2248 [==============================] - 8s - loss: 1.9070e-04
# Epoch 23/30
# 2248/2248 [==============================] - 9s - loss: 1.9524e-04
# Epoch 24/30
# 2248/2248 [==============================] - 9s - loss: 1.9165e-04
# Epoch 25/30
# 2248/2248 [==============================] - 9s - loss: 1.9106e-04
# Epoch 26/30
# 2248/2248 [==============================] - 8s - loss: 1.8261e-04
# Epoch 27/30
# 2248/2248 [==============================] - 8s - loss: 1.8117e-04
# Epoch 28/30
# 2248/2248 [==============================] - 8s - loss: 1.8510e-04
# Epoch 29/30
# 2248/2248 [==============================] - 8s - loss: 1.8610e-04
# Epoch 30/30
# 2248/2248 [==============================] - 8s - loss: 1.8554e-04
# ()
# LSTM: 61.4091273018
# CONV: 54.323458767
# DENSE: 51.0408326661
# CARA2: 60.0080064051
# ()
# Overall on everything: 58.0864691753
# Overall on test: 55.6

# %%
# Trend Voting
def evaluateY_trend(Y, YHat1, YHat2, YHat3, YHat4):
    total = len(Y)
    count = 0
    for i in range(1, total-1):
        t1 = 1 if YHat1[i] - YHat1[i-1] >= 0 else -1
        t2 = 1 if YHat2[i] - YHat2[i-1] >= 0 else -1
        t3 = 1 if YHat3[i] - YHat3[i-1] >= 0 else -1
        t4 = 1 if YHat4[i] - YHat4[i-1] >= 0 else -1
        if (0.5*t1 + 0.00*t2 + 0.00*t3 + 0.5*t4) * (Y[i] - Y[i-1]) >= 0:
            count += 1
    return (count * 100.0 / total)

print(evaluateY_trend(orderedY, orderedYHat_LSTM, orderedYHat_CONV, orderedYHat_DENSE, orderedYHat_CARA2))
# Out:
# 81.9455564452

# %%
# Ensemble with manual weights
from copy import deepcopy

def multiply_list(l, weight):
    l2 = []
    l2 = deepcopy([x * weight for x in l])
    return l2
# print(orderedYHat_LSTM)
# print(orderedYHat_CONV[0])
# print(orderedYHat_DENSE[0])

def weight_tweaking(w1, w2):
    man_YHat = []
    for i in range(YLen):
        x = (orderedYHat_LSTM[i]*w1 + orderedYHat_CONV[i]*w2 + orderedYHat_CARA2[i]*(1 - w1 - w2))
        man_YHat.append(x)
    return man_YHat

def grid_search():
    maxVal = 0
    w1, w2 = 0.1, 0.85
    while w1 < 0.9:
        w2 = 0.85 - w1
        while w2 > 0.1 and w1+w2 < 1:
            val = evaluateY(orderedY, weight_tweaking(w1, w2))
            maxVal = max(maxVal, val)
            print('Overall on everything:{}  ,  {} : {}'.format(w1, w2, val))
            w2 -= 0.01
        w1 += 0.01
    print("max val: {}".format(maxVal))
grid_search()  
# print len(man_YHat)
# print (man_YHat[0])
# Out:
# Overall on everything:0.1  ,  0.75 : 56.645316253
# Overall on everything:0.1  ,  0.74 : 56.3650920737
# Overall on everything:0.1  ,  0.73 : 56.4451561249
# Overall on everything:0.1  ,  0.72 : 56.5252201761
# Overall on everything:0.1  ,  0.71 : 56.6052842274
# Overall on everything:0.1  ,  0.7 : 56.6052842274
# Overall on everything:0.1  ,  0.69 : 56.7654123299
# Overall on everything:0.1  ,  0.68 : 56.6853482786
# Overall on everything:0.1  ,  0.67 : 56.8054443555
# Overall on everything:0.1  ,  0.66 : 57.0056044836
# Overall on everything:0.1  ,  0.65 : 57.0456365092
# Overall on everything:0.1  ,  0.64 : 57.1257005604
# Overall on everything:0.1  ,  0.63 : 57.0456365092
# Overall on everything:0.1  ,  0.62 : 57.0056044836
# Overall on everything:0.1  ,  0.61 : 57.0456365092
# Overall on everything:0.1  ,  0.6 : 57.1657325861
# Overall on everything:0.1  ,  0.59 : 57.4059247398
# Overall on everything:0.1  ,  0.58 : 57.4459567654
# Overall on everything:0.1  ,  0.57 : 57.5260208167
# Overall on everything:0.1  ,  0.56 : 57.6861489191
# Overall on everything:0.1  ,  0.55 : 57.6461168935
# Overall on everything:0.1  ,  0.54 : 57.6861489191
# Overall on everything:0.1  ,  0.53 : 57.6461168935
# Overall on everything:0.1  ,  0.52 : 57.7662129704
# Overall on everything:0.1  ,  0.51 : 57.9263410729
# Overall on everything:0.1  ,  0.5 : 57.9663730985
# Overall on everything:0.1  ,  0.49 : 58.0864691753
# Overall on everything:0.1  ,  0.48 : 58.0864691753
# Overall on everything:0.1  ,  0.47 : 58.126501201
# Overall on everything:0.1  ,  0.46 : 58.0864691753
# Overall on everything:0.1  ,  0.45 : 58.1665332266
# Overall on everything:0.1  ,  0.44 : 58.4067253803
# Overall on everything:0.1  ,  0.43 : 58.6068855084
# Overall on everything:0.1  ,  0.42 : 58.8070456365
# Overall on everything:0.1  ,  0.41 : 58.8470776621
# Overall on everything:0.1  ,  0.4 : 59.0072057646
# Overall on everything:0.1  ,  0.39 : 58.967173739
# Overall on everything:0.1  ,  0.38 : 58.9271417134
# Overall on everything:0.1  ,  0.37 : 58.9271417134
# Overall on everything:0.1  ,  0.36 : 59.0472377902
# Overall on everything:0.1  ,  0.35 : 59.2473979183
# Overall on everything:0.1  ,  0.34 : 59.2073658927
# Overall on everything:0.1  ,  0.33 : 59.2073658927
# Overall on everything:0.1  ,  0.32 : 59.4475580464
# Overall on everything:0.1  ,  0.31 : 59.6076861489
# Overall on everything:0.1  ,  0.3 : 59.6477181745
# Overall on everything:0.1  ,  0.29 : 59.7678142514
# Overall on everything:0.1  ,  0.28 : 59.7678142514
# Overall on everything:0.1  ,  0.27 : 59.9279423539
# Overall on everything:0.1  ,  0.26 : 59.8478783026
# Overall on everything:0.1  ,  0.25 : 59.8879103283
# Overall on everything:0.1  ,  0.24 : 59.9679743795
# Overall on everything:0.1  ,  0.23 : 59.8478783026
# Overall on everything:0.1  ,  0.22 : 59.9279423539
# Overall on everything:0.1  ,  0.21 : 59.8879103283
# Overall on everything:0.1  ,  0.2 : 59.7678142514
# Overall on everything:0.1  ,  0.19 : 59.9679743795
# Overall on everything:0.1  ,  0.18 : 59.9279423539
# Overall on everything:0.1  ,  0.17 : 59.9679743795
# Overall on everything:0.1  ,  0.16 : 59.9279423539
# Overall on everything:0.1  ,  0.15 : 59.9279423539
# Overall on everything:0.1  ,  0.14 : 59.9279423539
# Overall on everything:0.1  ,  0.13 : 59.9679743795
# Overall on everything:0.1  ,  0.12 : 60.128102482
# Overall on everything:0.1  ,  0.11 : 60.2882305845
# Overall on everything:0.11  ,  0.74 : 56.5252201761
# Overall on everything:0.11  ,  0.73 : 56.4851881505
# Overall on everything:0.11  ,  0.72 : 56.6052842274
# Overall on everything:0.11  ,  0.71 : 56.5652522018
# Overall on everything:0.11  ,  0.7 : 56.6853482786
# Overall on everything:0.11  ,  0.69 : 56.7654123299
# Overall on everything:0.11  ,  0.68 : 56.8054443555
# Overall on everything:0.11  ,  0.67 : 56.8855084067
# Overall on everything:0.11  ,  0.66 : 56.965572458
# Overall on everything:0.11  ,  0.65 : 57.0056044836
# Overall on everything:0.11  ,  0.64 : 57.0456365092
# Overall on everything:0.11  ,  0.63 : 57.0456365092
# Overall on everything:0.11  ,  0.62 : 57.0856685348
# Overall on everything:0.11  ,  0.61 : 57.0456365092
# Overall on everything:0.11  ,  0.6 : 57.1657325861
# Overall on everything:0.11  ,  0.59 : 57.3258606886
# Overall on everything:0.11  ,  0.58 : 57.5660528423
# Overall on everything:0.11  ,  0.57 : 57.6060848679
# Overall on everything:0.11  ,  0.56 : 57.6861489191
# Overall on everything:0.11  ,  0.55 : 57.6861489191
# Overall on everything:0.11  ,  0.54 : 57.7662129704
# Overall on everything:0.11  ,  0.53 : 57.7261809448
# Overall on everything:0.11  ,  0.52 : 57.8863090472
# Overall on everything:0.11  ,  0.51 : 57.9663730985
# Overall on everything:0.11  ,  0.5 : 58.126501201
# Overall on everything:0.11  ,  0.49 : 58.0864691753
# Overall on everything:0.11  ,  0.48 : 58.126501201
# Overall on everything:0.11  ,  0.47 : 58.0864691753
# Overall on everything:0.11  ,  0.46 : 58.2465972778
# Overall on everything:0.11  ,  0.45 : 58.3666933547
# Overall on everything:0.11  ,  0.44 : 58.4467574059
# Overall on everything:0.11  ,  0.43 : 58.4867894315
# Overall on everything:0.11  ,  0.42 : 58.8871096878
# Overall on everything:0.11  ,  0.41 : 58.9271417134
# Overall on everything:0.11  ,  0.4 : 59.0472377902
# Overall on everything:0.11  ,  0.39 : 59.0872698159
# Overall on everything:0.11  ,  0.38 : 59.0872698159
# Overall on everything:0.11  ,  0.37 : 59.0872698159
# Overall on everything:0.11  ,  0.36 : 59.0872698159
# Overall on everything:0.11  ,  0.35 : 59.3674939952
# Overall on everything:0.11  ,  0.34 : 59.3674939952
# Overall on everything:0.11  ,  0.33 : 59.3674939952
# Overall on everything:0.11  ,  0.32 : 59.4075260208
# Overall on everything:0.11  ,  0.31 : 59.6477181745
# Overall on everything:0.11  ,  0.3 : 59.6877502002
# Overall on everything:0.11  ,  0.29 : 59.8879103283
# Overall on everything:0.11  ,  0.28 : 59.8879103283
# Overall on everything:0.11  ,  0.27 : 60.0080064051
# Overall on everything:0.11  ,  0.26 : 60.0080064051
# Overall on everything:0.11  ,  0.25 : 59.8879103283
# Overall on everything:0.11  ,  0.24 : 59.9679743795
# Overall on everything:0.11  ,  0.23 : 59.9679743795
# Overall on everything:0.11  ,  0.22 : 60.0080064051
# Overall on everything:0.11  ,  0.21 : 59.8879103283
# Overall on everything:0.11  ,  0.2 : 59.7277822258
# Overall on everything:0.11  ,  0.19 : 59.9279423539
# Overall on everything:0.11  ,  0.18 : 60.0480384307
# Overall on everything:0.11  ,  0.17 : 60.128102482
# Overall on everything:0.11  ,  0.16 : 60.0480384307
# Overall on everything:0.11  ,  0.15 : 60.0880704564
# Overall on everything:0.11  ,  0.14 : 60.0480384307
# Overall on everything:0.11  ,  0.13 : 60.128102482
# Overall on everything:0.11  ,  0.12 : 60.1681345076
# Overall on everything:0.11  ,  0.11 : 60.2882305845
# Overall on everything:0.12  ,  0.73 : 56.5652522018
# Overall on everything:0.12  ,  0.72 : 56.6853482786
# Overall on everything:0.12  ,  0.71 : 56.7253803042
# Overall on everything:0.12  ,  0.7 : 56.6853482786
# Overall on everything:0.12  ,  0.69 : 56.7654123299
# Overall on everything:0.12  ,  0.68 : 56.7654123299
# Overall on everything:0.12  ,  0.67 : 56.7654123299
# Overall on everything:0.12  ,  0.66 : 57.0056044836
# Overall on everything:0.12  ,  0.65 : 57.0456365092
# Overall on everything:0.12  ,  0.64 : 57.0456365092
# Overall on everything:0.12  ,  0.63 : 57.0856685348
# Overall on everything:0.12  ,  0.62 : 57.0456365092
# Overall on everything:0.12  ,  0.61 : 57.0856685348
# Overall on everything:0.12  ,  0.6 : 57.0856685348
# Overall on everything:0.12  ,  0.59 : 57.3258606886
# Overall on everything:0.12  ,  0.58 : 57.5260208167
# Overall on everything:0.12  ,  0.57 : 57.6461168935
# Overall on everything:0.12  ,  0.56 : 57.7662129704
# Overall on everything:0.12  ,  0.55 : 57.7261809448
# Overall on everything:0.12  ,  0.54 : 57.7662129704
# Overall on everything:0.12  ,  0.53 : 57.8863090472
# Overall on everything:0.12  ,  0.52 : 57.8462770216
# Overall on everything:0.12  ,  0.51 : 57.8863090472
# Overall on everything:0.12  ,  0.5 : 58.1665332266
# Overall on everything:0.12  ,  0.49 : 58.2065652522
# Overall on everything:0.12  ,  0.48 : 58.3266613291
# Overall on everything:0.12  ,  0.47 : 58.3266613291
# Overall on everything:0.12  ,  0.46 : 58.2866293034
# Overall on everything:0.12  ,  0.45 : 58.2866293034
# Overall on everything:0.12  ,  0.44 : 58.3666933547
# Overall on everything:0.12  ,  0.43 : 58.4867894315
# Overall on everything:0.12  ,  0.42 : 58.6869495596
# Overall on everything:0.12  ,  0.41 : 59.0072057646
# Overall on everything:0.12  ,  0.4 : 58.967173739
# Overall on everything:0.12  ,  0.39 : 59.1273018415
# Overall on everything:0.12  ,  0.38 : 59.1273018415
# Overall on everything:0.12  ,  0.37 : 59.2073658927
# Overall on everything:0.12  ,  0.36 : 59.2073658927
# Overall on everything:0.12  ,  0.35 : 59.3674939952
# Overall on everything:0.12  ,  0.34 : 59.4475580464
# Overall on everything:0.12  ,  0.33 : 59.4075260208
# Overall on everything:0.12  ,  0.32 : 59.5676541233
# Overall on everything:0.12  ,  0.31 : 59.6076861489
# Overall on everything:0.12  ,  0.3 : 59.7678142514
# Overall on everything:0.12  ,  0.29 : 59.807846277
# Overall on everything:0.12  ,  0.28 : 59.8879103283
# Overall on everything:0.12  ,  0.27 : 59.9679743795
# Overall on everything:0.12  ,  0.26 : 59.9679743795
# Overall on everything:0.12  ,  0.25 : 60.0480384307
# Overall on everything:0.12  ,  0.24 : 60.0480384307
# Overall on everything:0.12  ,  0.23 : 60.128102482
# Overall on everything:0.12  ,  0.22 : 60.0080064051
# Overall on everything:0.12  ,  0.21 : 60.0080064051
# Overall on everything:0.12  ,  0.2 : 59.8478783026
# Overall on everything:0.12  ,  0.19 : 59.9279423539
# Overall on everything:0.12  ,  0.18 : 60.0480384307
# Overall on everything:0.12  ,  0.17 : 60.1681345076
# Overall on everything:0.12  ,  0.16 : 60.1681345076
# Overall on everything:0.12  ,  0.15 : 60.128102482
# Overall on everything:0.12  ,  0.14 : 60.1681345076
# Overall on everything:0.12  ,  0.13 : 60.2882305845
# Overall on everything:0.12  ,  0.12 : 60.2481985588
# Overall on everything:0.12  ,  0.11 : 60.3282626101
# Overall on everything:0.13  ,  0.72 : 56.8054443555
# Overall on everything:0.13  ,  0.71 : 56.7654123299
# Overall on everything:0.13  ,  0.7 : 56.8855084067
# Overall on everything:0.13  ,  0.69 : 56.8054443555
# Overall on everything:0.13  ,  0.68 : 56.7654123299
# Overall on everything:0.13  ,  0.67 : 56.8054443555
# Overall on everything:0.13  ,  0.66 : 56.965572458
# Overall on everything:0.13  ,  0.65 : 57.0056044836
# Overall on everything:0.13  ,  0.64 : 56.965572458
# Overall on everything:0.13  ,  0.63 : 57.0456365092
# Overall on everything:0.13  ,  0.62 : 57.1257005604
# Overall on everything:0.13  ,  0.61 : 57.0456365092
# Overall on everything:0.13  ,  0.6 : 57.0856685348
# Overall on everything:0.13  ,  0.59 : 57.3658927142
# Overall on everything:0.13  ,  0.58 : 57.5260208167
# Overall on everything:0.13  ,  0.57 : 57.6861489191
# Overall on everything:0.13  ,  0.56 : 57.8462770216
# Overall on everything:0.13  ,  0.55 : 57.9263410729
# Overall on everything:0.13  ,  0.54 : 57.8462770216
# Overall on everything:0.13  ,  0.53 : 58.0064051241
# Overall on everything:0.13  ,  0.52 : 58.0064051241
# Overall on everything:0.13  ,  0.51 : 57.8863090472
# Overall on everything:0.13  ,  0.5 : 58.0464371497
# Overall on everything:0.13  ,  0.49 : 58.3266613291
# Overall on everything:0.13  ,  0.48 : 58.6068855084
# Overall on everything:0.13  ,  0.47 : 58.4867894315
# Overall on everything:0.13  ,  0.46 : 58.3666933547
# Overall on everything:0.13  ,  0.45 : 58.3666933547
# Overall on everything:0.13  ,  0.44 : 58.3266613291
# Overall on everything:0.13  ,  0.43 : 58.5268214572
# Overall on everything:0.13  ,  0.42 : 58.7269815853
# Overall on everything:0.13  ,  0.41 : 58.8871096878
# Overall on everything:0.13  ,  0.4 : 59.0072057646
# Overall on everything:0.13  ,  0.39 : 59.1673338671
# Overall on everything:0.13  ,  0.38 : 59.2073658927
# Overall on everything:0.13  ,  0.37 : 59.3274619696
# Overall on everything:0.13  ,  0.36 : 59.3674939952
# Overall on everything:0.13  ,  0.35 : 59.4075260208
# Overall on everything:0.13  ,  0.34 : 59.5276220977
# Overall on everything:0.13  ,  0.33 : 59.5276220977
# Overall on everything:0.13  ,  0.32 : 59.5276220977
# Overall on everything:0.13  ,  0.31 : 59.5676541233
# Overall on everything:0.13  ,  0.3 : 59.7277822258
# Overall on everything:0.13  ,  0.29 : 59.7678142514
# Overall on everything:0.13  ,  0.28 : 59.9279423539
# Overall on everything:0.13  ,  0.27 : 59.9279423539
# Overall on everything:0.13  ,  0.26 : 59.9279423539
# Overall on everything:0.13  ,  0.25 : 59.9679743795
# Overall on everything:0.13  ,  0.24 : 60.0480384307
# Overall on everything:0.13  ,  0.23 : 60.2081665332
# Overall on everything:0.13  ,  0.22 : 60.2081665332
# Overall on everything:0.13  ,  0.21 : 60.0480384307
# Overall on everything:0.13  ,  0.2 : 59.9279423539
# Overall on everything:0.13  ,  0.19 : 59.9279423539
# Overall on everything:0.13  ,  0.18 : 60.0880704564
# Overall on everything:0.13  ,  0.17 : 59.9679743795
# Overall on everything:0.13  ,  0.16 : 60.128102482
# Overall on everything:0.13  ,  0.15 : 60.1681345076
# Overall on everything:0.13  ,  0.14 : 60.128102482
# Overall on everything:0.13  ,  0.13 : 60.2882305845
# Overall on everything:0.13  ,  0.12 : 60.3682946357
# Overall on everything:0.13  ,  0.11 : 60.3682946357
# Overall on everything:0.14  ,  0.71 : 56.8054443555
# Overall on everything:0.14  ,  0.7 : 56.8454763811
# Overall on everything:0.14  ,  0.69 : 56.7654123299
# Overall on everything:0.14  ,  0.68 : 56.8054443555
# Overall on everything:0.14  ,  0.67 : 56.8054443555
# Overall on everything:0.14  ,  0.66 : 56.8855084067
# Overall on everything:0.14  ,  0.65 : 56.965572458
# Overall on everything:0.14  ,  0.64 : 56.9255404323
# Overall on everything:0.14  ,  0.63 : 57.0056044836
# Overall on everything:0.14  ,  0.62 : 57.0856685348
# Overall on everything:0.14  ,  0.61 : 57.2057646117
# Overall on everything:0.14  ,  0.6 : 57.1657325861
# Overall on everything:0.14  ,  0.59 : 57.3258606886
# Overall on everything:0.14  ,  0.58 : 57.485988791
# Overall on everything:0.14  ,  0.57 : 57.6060848679
# Overall on everything:0.14  ,  0.56 : 57.806244996
# Overall on everything:0.14  ,  0.55 : 58.0464371497
# Overall on everything:0.14  ,  0.54 : 57.9663730985
# Overall on everything:0.14  ,  0.53 : 58.0064051241
# Overall on everything:0.14  ,  0.52 : 58.0464371497
# Overall on everything:0.14  ,  0.51 : 58.126501201
# Overall on everything:0.14  ,  0.5 : 58.1665332266
# Overall on everything:0.14  ,  0.49 : 58.3266613291
# Overall on everything:0.14  ,  0.48 : 58.4867894315
# Overall on everything:0.14  ,  0.47 : 58.6869495596
# Overall on everything:0.14  ,  0.46 : 58.3666933547
# Overall on everything:0.14  ,  0.45 : 58.3266613291
# Overall on everything:0.14  ,  0.44 : 58.4067253803
# Overall on everything:0.14  ,  0.43 : 58.4067253803
# Overall on everything:0.14  ,  0.42 : 58.6068855084
# Overall on everything:0.14  ,  0.41 : 58.8470776621
# Overall on everything:0.14  ,  0.4 : 58.8871096878
# Overall on everything:0.14  ,  0.39 : 59.0872698159
# Overall on everything:0.14  ,  0.38 : 59.2473979183
# Overall on everything:0.14  ,  0.37 : 59.287429944
# Overall on everything:0.14  ,  0.36 : 59.3674939952
# Overall on everything:0.14  ,  0.35 : 59.4875900721
# Overall on everything:0.14  ,  0.34 : 59.4875900721
# Overall on everything:0.14  ,  0.33 : 59.4475580464
# Overall on everything:0.14  ,  0.32 : 59.6477181745
# Overall on everything:0.14  ,  0.31 : 59.7277822258
# Overall on everything:0.14  ,  0.3 : 59.6877502002
# Overall on everything:0.14  ,  0.29 : 59.807846277
# Overall on everything:0.14  ,  0.28 : 59.8478783026
# Overall on everything:0.14  ,  0.27 : 59.9279423539
# Overall on everything:0.14  ,  0.26 : 60.0080064051
# Overall on everything:0.14  ,  0.25 : 59.9679743795
# Overall on everything:0.14  ,  0.24 : 59.9679743795
# Overall on everything:0.14  ,  0.23 : 60.2081665332
# Overall on everything:0.14  ,  0.22 : 60.2081665332
# Overall on everything:0.14  ,  0.21 : 60.0880704564
# Overall on everything:0.14  ,  0.2 : 60.128102482
# Overall on everything:0.14  ,  0.19 : 60.0480384307
# Overall on everything:0.14  ,  0.18 : 60.2081665332
# Overall on everything:0.14  ,  0.17 : 60.0880704564
# Overall on everything:0.14  ,  0.16 : 60.0880704564
# Overall on everything:0.14  ,  0.15 : 60.3282626101
# Overall on everything:0.14  ,  0.14 : 60.1681345076
# Overall on everything:0.14  ,  0.13 : 60.2882305845
# Overall on everything:0.14  ,  0.12 : 60.3682946357
# Overall on everything:0.14  ,  0.11 : 60.3282626101
# Overall on everything:0.15  ,  0.7 : 56.7654123299
# Overall on everything:0.15  ,  0.69 : 56.8454763811
# Overall on everything:0.15  ,  0.68 : 56.7654123299
# Overall on everything:0.15  ,  0.67 : 56.6853482786
# Overall on everything:0.15  ,  0.66 : 56.8454763811
# Overall on everything:0.15  ,  0.65 : 56.9255404323
# Overall on everything:0.15  ,  0.64 : 56.8855084067
# Overall on everything:0.15  ,  0.63 : 56.9255404323
# Overall on everything:0.15  ,  0.62 : 57.0456365092
# Overall on everything:0.15  ,  0.61 : 57.1257005604
# Overall on everything:0.15  ,  0.6 : 57.1657325861
# Overall on everything:0.15  ,  0.59 : 57.3258606886
# Overall on everything:0.15  ,  0.58 : 57.5260208167
# Overall on everything:0.15  ,  0.57 : 57.6861489191
# Overall on everything:0.15  ,  0.56 : 57.8863090472
# Overall on everything:0.15  ,  0.55 : 58.0864691753
# Overall on everything:0.15  ,  0.54 : 58.0864691753
# Overall on everything:0.15  ,  0.53 : 58.1665332266
# Overall on everything:0.15  ,  0.52 : 58.2465972778
# Overall on everything:0.15  ,  0.51 : 58.2065652522
# Overall on everything:0.15  ,  0.5 : 58.2866293034
# Overall on everything:0.15  ,  0.49 : 58.3666933547
# Overall on everything:0.15  ,  0.48 : 58.5668534828
# Overall on everything:0.15  ,  0.47 : 58.6869495596
# Overall on everything:0.15  ,  0.46 : 58.5668534828
# Overall on everything:0.15  ,  0.45 : 58.4067253803
# Overall on everything:0.15  ,  0.44 : 58.4067253803
# Overall on everything:0.15  ,  0.43 : 58.5268214572
# Overall on everything:0.15  ,  0.42 : 58.6869495596
# Overall on everything:0.15  ,  0.41 : 58.8871096878
# Overall on everything:0.15  ,  0.4 : 58.8470776621
# Overall on everything:0.15  ,  0.39 : 58.9271417134
# Overall on everything:0.15  ,  0.38 : 59.0872698159
# Overall on everything:0.15  ,  0.37 : 59.2073658927
# Overall on everything:0.15  ,  0.36 : 59.3274619696
# Overall on everything:0.15  ,  0.35 : 59.4075260208
# Overall on everything:0.15  ,  0.34 : 59.5676541233
# Overall on everything:0.15  ,  0.33 : 59.5276220977
# Overall on everything:0.15  ,  0.32 : 59.6477181745
# Overall on everything:0.15  ,  0.31 : 59.7277822258
# Overall on everything:0.15  ,  0.3 : 59.807846277
# Overall on everything:0.15  ,  0.29 : 59.9279423539
# Overall on everything:0.15  ,  0.28 : 59.8879103283
# Overall on everything:0.15  ,  0.27 : 59.807846277
# Overall on everything:0.15  ,  0.26 : 59.8879103283
# Overall on everything:0.15  ,  0.25 : 60.0480384307
# Overall on everything:0.15  ,  0.24 : 59.9279423539
# Overall on everything:0.15  ,  0.23 : 60.0880704564
# Overall on everything:0.15  ,  0.22 : 60.2481985588
# Overall on everything:0.15  ,  0.21 : 60.0080064051
# Overall on everything:0.15  ,  0.2 : 60.128102482
# Overall on everything:0.15  ,  0.19 : 60.2081665332
# Overall on everything:0.15  ,  0.18 : 60.3282626101
# Overall on everything:0.15  ,  0.17 : 60.2081665332
# Overall on everything:0.15  ,  0.16 : 60.0480384307
# Overall on everything:0.15  ,  0.15 : 60.2481985588
# Overall on everything:0.15  ,  0.14 : 60.1681345076
# Overall on everything:0.15  ,  0.13 : 60.4083266613
# Overall on everything:0.15  ,  0.12 : 60.4083266613
# Overall on everything:0.15  ,  0.11 : 60.3282626101
# Overall on everything:0.16  ,  0.69 : 56.8454763811
# Overall on everything:0.16  ,  0.68 : 56.8454763811
# Overall on everything:0.16  ,  0.67 : 56.7253803042
# Overall on everything:0.16  ,  0.66 : 56.8054443555
# Overall on everything:0.16  ,  0.65 : 56.8454763811
# Overall on everything:0.16  ,  0.64 : 56.8454763811
# Overall on everything:0.16  ,  0.63 : 56.8855084067
# Overall on everything:0.16  ,  0.62 : 57.0056044836
# Overall on everything:0.16  ,  0.61 : 57.1657325861
# Overall on everything:0.16  ,  0.6 : 57.2057646117
# Overall on everything:0.16  ,  0.59 : 57.3658927142
# Overall on everything:0.16  ,  0.58 : 57.6060848679
# Overall on everything:0.16  ,  0.57 : 57.806244996
# Overall on everything:0.16  ,  0.56 : 57.806244996
# Overall on everything:0.16  ,  0.55 : 58.126501201
# Overall on everything:0.16  ,  0.54 : 58.2866293034
# Overall on everything:0.16  ,  0.53 : 58.3266613291
# Overall on everything:0.16  ,  0.52 : 58.4067253803
# Overall on everything:0.16  ,  0.51 : 58.3666933547
# Overall on everything:0.16  ,  0.5 : 58.3666933547
# Overall on everything:0.16  ,  0.49 : 58.4467574059
# Overall on everything:0.16  ,  0.48 : 58.5668534828
# Overall on everything:0.16  ,  0.47 : 58.6869495596
# Overall on everything:0.16  ,  0.46 : 58.6068855084
# Overall on everything:0.16  ,  0.45 : 58.5268214572
# Overall on everything:0.16  ,  0.44 : 58.4467574059
# Overall on everything:0.16  ,  0.43 : 58.4867894315
# Overall on everything:0.16  ,  0.42 : 58.6869495596
# Overall on everything:0.16  ,  0.41 : 58.7670136109
# Overall on everything:0.16  ,  0.4 : 58.8871096878
# Overall on everything:0.16  ,  0.39 : 59.0072057646
# Overall on everything:0.16  ,  0.38 : 59.0472377902
# Overall on everything:0.16  ,  0.37 : 59.1673338671
# Overall on everything:0.16  ,  0.36 : 59.4075260208
# Overall on everything:0.16  ,  0.35 : 59.3674939952
# Overall on everything:0.16  ,  0.34 : 59.5676541233
# Overall on everything:0.16  ,  0.33 : 59.5676541233
# Overall on everything:0.16  ,  0.32 : 59.6877502002
# Overall on everything:0.16  ,  0.31 : 59.7277822258
# Overall on everything:0.16  ,  0.3 : 59.7678142514
# Overall on everything:0.16  ,  0.29 : 59.9279423539
# Overall on everything:0.16  ,  0.28 : 59.8478783026
# Overall on everything:0.16  ,  0.27 : 59.9279423539
# Overall on everything:0.16  ,  0.26 : 59.8879103283
# Overall on everything:0.16  ,  0.25 : 60.0480384307
# Overall on everything:0.16  ,  0.24 : 60.0080064051
# Overall on everything:0.16  ,  0.23 : 60.0480384307
# Overall on everything:0.16  ,  0.22 : 60.1681345076
# Overall on everything:0.16  ,  0.21 : 60.0480384307
# Overall on everything:0.16  ,  0.2 : 60.1681345076
# Overall on everything:0.16  ,  0.19 : 60.2081665332
# Overall on everything:0.16  ,  0.18 : 60.3282626101
# Overall on everything:0.16  ,  0.17 : 60.3282626101
# Overall on everything:0.16  ,  0.16 : 60.3282626101
# Overall on everything:0.16  ,  0.15 : 60.1681345076
# Overall on everything:0.16  ,  0.14 : 60.3282626101
# Overall on everything:0.16  ,  0.13 : 60.4483586869
# Overall on everything:0.16  ,  0.12 : 60.5284227382
# Overall on everything:0.16  ,  0.11 : 60.4083266613
# Overall on everything:0.17  ,  0.68 : 56.8454763811
# Overall on everything:0.17  ,  0.67 : 56.7253803042
# Overall on everything:0.17  ,  0.66 : 56.7654123299
# Overall on everything:0.17  ,  0.65 : 56.7654123299
# Overall on everything:0.17  ,  0.64 : 56.9255404323
# Overall on everything:0.17  ,  0.63 : 56.8454763811
# Overall on everything:0.17  ,  0.62 : 56.965572458
# Overall on everything:0.17  ,  0.61 : 57.0456365092
# Overall on everything:0.17  ,  0.6 : 57.1257005604
# Overall on everything:0.17  ,  0.59 : 57.3258606886
# Overall on everything:0.17  ,  0.58 : 57.6060848679
# Overall on everything:0.17  ,  0.57 : 57.7662129704
# Overall on everything:0.17  ,  0.56 : 57.8863090472
# Overall on everything:0.17  ,  0.55 : 58.1665332266
# Overall on everything:0.17  ,  0.54 : 58.3266613291
# Overall on everything:0.17  ,  0.53 : 58.4067253803
# Overall on everything:0.17  ,  0.52 : 58.4067253803
# Overall on everything:0.17  ,  0.51 : 58.4067253803
# Overall on everything:0.17  ,  0.5 : 58.4067253803
# Overall on everything:0.17  ,  0.49 : 58.4067253803
# Overall on everything:0.17  ,  0.48 : 58.646917534
# Overall on everything:0.17  ,  0.47 : 58.7269815853
# Overall on everything:0.17  ,  0.46 : 58.646917534
# Overall on everything:0.17  ,  0.45 : 58.6068855084
# Overall on everything:0.17  ,  0.44 : 58.5668534828
# Overall on everything:0.17  ,  0.43 : 58.4867894315
# Overall on everything:0.17  ,  0.42 : 58.646917534
# Overall on everything:0.17  ,  0.41 : 58.7670136109
# Overall on everything:0.17  ,  0.4 : 58.8871096878
# Overall on everything:0.17  ,  0.39 : 58.9271417134
# Overall on everything:0.17  ,  0.38 : 59.0872698159
# Overall on everything:0.17  ,  0.37 : 59.1273018415
# Overall on everything:0.17  ,  0.36 : 59.2473979183
# Overall on everything:0.17  ,  0.35 : 59.287429944
# Overall on everything:0.17  ,  0.34 : 59.5276220977
# Overall on everything:0.17  ,  0.33 : 59.7277822258
# Overall on everything:0.17  ,  0.32 : 59.807846277
# Overall on everything:0.17  ,  0.31 : 59.7277822258
# Overall on everything:0.17  ,  0.3 : 59.7678142514
# Overall on everything:0.17  ,  0.29 : 59.6877502002
# Overall on everything:0.17  ,  0.28 : 59.7678142514
# Overall on everything:0.17  ,  0.27 : 59.9279423539
# Overall on everything:0.17  ,  0.26 : 59.8879103283
# Overall on everything:0.17  ,  0.25 : 59.9279423539
# Overall on everything:0.17  ,  0.24 : 60.0080064051
# Overall on everything:0.17  ,  0.23 : 59.9679743795
# Overall on everything:0.17  ,  0.22 : 60.0480384307
# Overall on everything:0.17  ,  0.21 : 60.0480384307
# Overall on everything:0.17  ,  0.2 : 60.1681345076
# Overall on everything:0.17  ,  0.19 : 60.1681345076
# Overall on everything:0.17  ,  0.18 : 60.3282626101
# Overall on everything:0.17  ,  0.17 : 60.3282626101
# Overall on everything:0.17  ,  0.16 : 60.3682946357
# Overall on everything:0.17  ,  0.15 : 60.2882305845
# Overall on everything:0.17  ,  0.14 : 60.3282626101
# Overall on everything:0.17  ,  0.13 : 60.4883907126
# Overall on everything:0.17  ,  0.12 : 60.5284227382
# Overall on everything:0.17  ,  0.11 : 60.5284227382
# Overall on everything:0.18  ,  0.67 : 56.8054443555
# Overall on everything:0.18  ,  0.66 : 56.7654123299
# Overall on everything:0.18  ,  0.65 : 56.6853482786
# Overall on everything:0.18  ,  0.64 : 56.8855084067
# Overall on everything:0.18  ,  0.63 : 56.965572458
# Overall on everything:0.18  ,  0.62 : 56.8855084067
# Overall on everything:0.18  ,  0.61 : 57.0056044836
# Overall on everything:0.18  ,  0.6 : 57.0856685348
# Overall on everything:0.18  ,  0.59 : 57.3258606886
# Overall on everything:0.18  ,  0.58 : 57.485988791
# Overall on everything:0.18  ,  0.57 : 57.8863090472
# Overall on everything:0.18  ,  0.56 : 57.9263410729
# Overall on everything:0.18  ,  0.55 : 57.9663730985
# Overall on everything:0.18  ,  0.54 : 58.3666933547
# Overall on everything:0.18  ,  0.53 : 58.4467574059
# Overall on everything:0.18  ,  0.52 : 58.4067253803
# Overall on everything:0.18  ,  0.51 : 58.4467574059
# Overall on everything:0.18  ,  0.5 : 58.4067253803
# Overall on everything:0.18  ,  0.49 : 58.3666933547
# Overall on everything:0.18  ,  0.48 : 58.5668534828
# Overall on everything:0.18  ,  0.47 : 58.7269815853
# Overall on everything:0.18  ,  0.46 : 58.7269815853
# Overall on everything:0.18  ,  0.45 : 58.6068855084
# Overall on everything:0.18  ,  0.44 : 58.6068855084
# Overall on everything:0.18  ,  0.43 : 58.646917534
# Overall on everything:0.18  ,  0.42 : 58.6869495596
# Overall on everything:0.18  ,  0.41 : 58.6869495596
# Overall on everything:0.18  ,  0.4 : 58.967173739
# Overall on everything:0.18  ,  0.39 : 59.0472377902
# Overall on everything:0.18  ,  0.38 : 59.0472377902
# Overall on everything:0.18  ,  0.37 : 59.0872698159
# Overall on everything:0.18  ,  0.36 : 59.2473979183
# Overall on everything:0.18  ,  0.35 : 59.3674939952
# Overall on everything:0.18  ,  0.34 : 59.4075260208
# Overall on everything:0.18  ,  0.33 : 59.6477181745
# Overall on everything:0.18  ,  0.32 : 59.807846277
# Overall on everything:0.18  ,  0.31 : 59.7277822258
# Overall on everything:0.18  ,  0.3 : 59.7678142514
# Overall on everything:0.18  ,  0.29 : 59.7678142514
# Overall on everything:0.18  ,  0.28 : 59.6477181745
# Overall on everything:0.18  ,  0.27 : 59.8879103283
# Overall on everything:0.18  ,  0.26 : 59.9279423539
# Overall on everything:0.18  ,  0.25 : 59.8478783026
# Overall on everything:0.18  ,  0.24 : 59.9279423539
# Overall on everything:0.18  ,  0.23 : 60.0080064051
# Overall on everything:0.18  ,  0.22 : 60.0080064051
# Overall on everything:0.18  ,  0.21 : 60.0080064051
# Overall on everything:0.18  ,  0.2 : 60.128102482
# Overall on everything:0.18  ,  0.19 : 60.128102482
# Overall on everything:0.18  ,  0.18 : 60.2481985588
# Overall on everything:0.18  ,  0.17 : 60.3282626101
# Overall on everything:0.18  ,  0.16 : 60.4083266613
# Overall on everything:0.18  ,  0.15 : 60.4483586869
# Overall on everything:0.18  ,  0.14 : 60.4083266613
# Overall on everything:0.18  ,  0.13 : 60.3682946357
# Overall on everything:0.18  ,  0.12 : 60.4883907126
# Overall on everything:0.18  ,  0.11 : 60.4883907126
# Overall on everything:0.19  ,  0.66 : 56.7253803042
# Overall on everything:0.19  ,  0.65 : 56.8454763811
# Overall on everything:0.19  ,  0.64 : 56.8855084067
# Overall on everything:0.19  ,  0.63 : 56.9255404323
# Overall on everything:0.19  ,  0.62 : 57.1257005604
# Overall on everything:0.19  ,  0.61 : 57.2057646117
# Overall on everything:0.19  ,  0.6 : 57.0856685348
# Overall on everything:0.19  ,  0.59 : 57.4059247398
# Overall on everything:0.19  ,  0.58 : 57.5260208167
# Overall on everything:0.19  ,  0.57 : 57.806244996
# Overall on everything:0.19  ,  0.56 : 57.9263410729
# Overall on everything:0.19  ,  0.55 : 58.0464371497
# Overall on everything:0.19  ,  0.54 : 58.2065652522
# Overall on everything:0.19  ,  0.53 : 58.2866293034
# Overall on everything:0.19  ,  0.52 : 58.2866293034
# Overall on everything:0.19  ,  0.51 : 58.4867894315
# Overall on everything:0.19  ,  0.5 : 58.3666933547
# Overall on everything:0.19  ,  0.49 : 58.4067253803
# Overall on everything:0.19  ,  0.48 : 58.4467574059
# Overall on everything:0.19  ,  0.47 : 58.6068855084
# Overall on everything:0.19  ,  0.46 : 58.7269815853
# Overall on everything:0.19  ,  0.45 : 58.6068855084
# Overall on everything:0.19  ,  0.44 : 58.7269815853
# Overall on everything:0.19  ,  0.43 : 58.8070456365
# Overall on everything:0.19  ,  0.42 : 58.6869495596
# Overall on everything:0.19  ,  0.41 : 58.8070456365
# Overall on everything:0.19  ,  0.4 : 58.8871096878
# Overall on everything:0.19  ,  0.39 : 59.0872698159
# Overall on everything:0.19  ,  0.38 : 59.0072057646
# Overall on everything:0.19  ,  0.37 : 59.0872698159
# Overall on everything:0.19  ,  0.36 : 59.1673338671
# Overall on everything:0.19  ,  0.35 : 59.3274619696
# Overall on everything:0.19  ,  0.34 : 59.4475580464
# Overall on everything:0.19  ,  0.33 : 59.5676541233
# Overall on everything:0.19  ,  0.32 : 59.7277822258
# Overall on everything:0.19  ,  0.31 : 59.807846277
# Overall on everything:0.19  ,  0.3 : 59.6877502002
# Overall on everything:0.19  ,  0.29 : 59.7277822258
# Overall on everything:0.19  ,  0.28 : 59.7277822258
# Overall on everything:0.19  ,  0.27 : 59.7277822258
# Overall on everything:0.19  ,  0.26 : 59.8879103283
# Overall on everything:0.19  ,  0.25 : 59.9279423539
# Overall on everything:0.19  ,  0.24 : 59.9679743795
# Overall on everything:0.19  ,  0.23 : 59.9279423539
# Overall on everything:0.19  ,  0.22 : 59.8879103283
# Overall on everything:0.19  ,  0.21 : 60.0480384307
# Overall on everything:0.19  ,  0.2 : 60.128102482
# Overall on everything:0.19  ,  0.19 : 60.1681345076
# Overall on everything:0.19  ,  0.18 : 60.4483586869
# Overall on everything:0.19  ,  0.17 : 60.4083266613
# Overall on everything:0.19  ,  0.16 : 60.4483586869
# Overall on everything:0.19  ,  0.15 : 60.4883907126
# Overall on everything:0.19  ,  0.14 : 60.4483586869
# Overall on everything:0.19  ,  0.13 : 60.4483586869
# Overall on everything:0.19  ,  0.12 : 60.5684547638
# Overall on everything:0.19  ,  0.11 : 60.4483586869
# Overall on everything:0.2  ,  0.65 : 56.8454763811
# Overall on everything:0.2  ,  0.64 : 56.9255404323
# Overall on everything:0.2  ,  0.63 : 57.0456365092
# Overall on everything:0.2  ,  0.62 : 57.0856685348
# Overall on everything:0.2  ,  0.61 : 57.1257005604
# Overall on everything:0.2  ,  0.6 : 57.2057646117
# Overall on everything:0.2  ,  0.59 : 57.2457966373
# Overall on everything:0.2  ,  0.58 : 57.4459567654
# Overall on everything:0.2  ,  0.57 : 57.7261809448
# Overall on everything:0.2  ,  0.56 : 57.806244996
# Overall on everything:0.2  ,  0.55 : 57.9263410729
# Overall on everything:0.2  ,  0.54 : 58.0864691753
# Overall on everything:0.2  ,  0.53 : 58.2465972778
# Overall on everything:0.2  ,  0.52 : 58.2866293034
# Overall on everything:0.2  ,  0.51 : 58.4467574059
# Overall on everything:0.2  ,  0.5 : 58.4467574059
# Overall on everything:0.2  ,  0.49 : 58.5268214572
# Overall on everything:0.2  ,  0.48 : 58.5668534828
# Overall on everything:0.2  ,  0.47 : 58.5668534828
# Overall on everything:0.2  ,  0.46 : 58.7269815853
# Overall on everything:0.2  ,  0.45 : 58.7269815853
# Overall on everything:0.2  ,  0.44 : 58.6869495596
# Overall on everything:0.2  ,  0.43 : 58.8070456365
# Overall on everything:0.2  ,  0.42 : 58.8070456365
# Overall on everything:0.2  ,  0.41 : 58.8470776621
# Overall on everything:0.2  ,  0.4 : 58.9271417134
# Overall on everything:0.2  ,  0.39 : 59.0872698159
# Overall on everything:0.2  ,  0.38 : 59.0872698159
# Overall on everything:0.2  ,  0.37 : 59.1273018415
# Overall on everything:0.2  ,  0.36 : 59.2073658927
# Overall on everything:0.2  ,  0.35 : 59.287429944
# Overall on everything:0.2  ,  0.34 : 59.3674939952
# Overall on everything:0.2  ,  0.33 : 59.6076861489
# Overall on everything:0.2  ,  0.32 : 59.7277822258
# Overall on everything:0.2  ,  0.31 : 59.6877502002
# Overall on everything:0.2  ,  0.3 : 59.6076861489
# Overall on everything:0.2  ,  0.29 : 59.6477181745
# Overall on everything:0.2  ,  0.28 : 59.6477181745
# Overall on everything:0.2  ,  0.27 : 59.7277822258
# Overall on everything:0.2  ,  0.26 : 59.7678142514
# Overall on everything:0.2  ,  0.25 : 59.8879103283
# Overall on everything:0.2  ,  0.24 : 59.8879103283
# Overall on everything:0.2  ,  0.23 : 59.807846277
# Overall on everything:0.2  ,  0.22 : 59.8879103283
# Overall on everything:0.2  ,  0.21 : 60.0480384307
# Overall on everything:0.2  ,  0.2 : 60.128102482
# Overall on everything:0.2  ,  0.19 : 60.3282626101
# Overall on everything:0.2  ,  0.18 : 60.4483586869
# Overall on everything:0.2  ,  0.17 : 60.4483586869
# Overall on everything:0.2  ,  0.16 : 60.3682946357
# Overall on everything:0.2  ,  0.15 : 60.4883907126
# Overall on everything:0.2  ,  0.14 : 60.4483586869
# Overall on everything:0.2  ,  0.13 : 60.4083266613
# Overall on everything:0.2  ,  0.12 : 60.4483586869
# Overall on everything:0.2  ,  0.11 : 60.5684547638
# Overall on everything:0.21  ,  0.64 : 57.0456365092
# Overall on everything:0.21  ,  0.63 : 57.1257005604
# Overall on everything:0.21  ,  0.62 : 57.2457966373
# Overall on everything:0.21  ,  0.61 : 57.2858286629
# Overall on everything:0.21  ,  0.6 : 57.1657325861
# Overall on everything:0.21  ,  0.59 : 57.2457966373
# Overall on everything:0.21  ,  0.58 : 57.3258606886
# Overall on everything:0.21  ,  0.57 : 57.6060848679
# Overall on everything:0.21  ,  0.56 : 57.8462770216
# Overall on everything:0.21  ,  0.55 : 57.8863090472
# Overall on everything:0.21  ,  0.54 : 58.126501201
# Overall on everything:0.21  ,  0.53 : 58.1665332266
# Overall on everything:0.21  ,  0.52 : 58.2065652522
# Overall on everything:0.21  ,  0.51 : 58.4067253803
# Overall on everything:0.21  ,  0.5 : 58.4867894315
# Overall on everything:0.21  ,  0.49 : 58.6068855084
# Overall on everything:0.21  ,  0.48 : 58.646917534
# Overall on everything:0.21  ,  0.47 : 58.6068855084
# Overall on everything:0.21  ,  0.46 : 58.6869495596
# Overall on everything:0.21  ,  0.45 : 58.7269815853
# Overall on everything:0.21  ,  0.44 : 58.7269815853
# Overall on everything:0.21  ,  0.43 : 58.8070456365
# Overall on everything:0.21  ,  0.42 : 58.8871096878
# Overall on everything:0.21  ,  0.41 : 58.8871096878
# Overall on everything:0.21  ,  0.4 : 58.967173739
# Overall on everything:0.21  ,  0.39 : 59.1273018415
# Overall on everything:0.21  ,  0.38 : 59.1273018415
# Overall on everything:0.21  ,  0.37 : 59.0872698159
# Overall on everything:0.21  ,  0.36 : 59.1673338671
# Overall on everything:0.21  ,  0.35 : 59.287429944
# Overall on everything:0.21  ,  0.34 : 59.3674939952
# Overall on everything:0.21  ,  0.33 : 59.5676541233
# Overall on everything:0.21  ,  0.32 : 59.7678142514
# Overall on everything:0.21  ,  0.31 : 59.7277822258
# Overall on everything:0.21  ,  0.3 : 59.6877502002
# Overall on everything:0.21  ,  0.29 : 59.6477181745
# Overall on everything:0.21  ,  0.28 : 59.6076861489
# Overall on everything:0.21  ,  0.27 : 59.6877502002
# Overall on everything:0.21  ,  0.26 : 59.807846277
# Overall on everything:0.21  ,  0.25 : 59.8879103283
# Overall on everything:0.21  ,  0.24 : 59.9279423539
# Overall on everything:0.21  ,  0.23 : 59.807846277
# Overall on everything:0.21  ,  0.22 : 59.9279423539
# Overall on everything:0.21  ,  0.21 : 59.9679743795
# Overall on everything:0.21  ,  0.2 : 60.128102482
# Overall on everything:0.21  ,  0.19 : 60.2882305845
# Overall on everything:0.21  ,  0.18 : 60.4483586869
# Overall on everything:0.21  ,  0.17 : 60.4883907126
# Overall on everything:0.21  ,  0.16 : 60.4083266613
# Overall on everything:0.21  ,  0.15 : 60.3682946357
# Overall on everything:0.21  ,  0.14 : 60.3282626101
# Overall on everything:0.21  ,  0.13 : 60.3282626101
# Overall on everything:0.21  ,  0.12 : 60.4083266613
# Overall on everything:0.21  ,  0.11 : 60.4483586869
# Overall on everything:0.22  ,  0.63 : 57.1257005604
# Overall on everything:0.22  ,  0.62 : 57.2858286629
# Overall on everything:0.22  ,  0.61 : 57.2457966373
# Overall on everything:0.22  ,  0.6 : 57.2858286629
# Overall on everything:0.22  ,  0.59 : 57.2858286629
# Overall on everything:0.22  ,  0.58 : 57.3658927142
# Overall on everything:0.22  ,  0.57 : 57.6060848679
# Overall on everything:0.22  ,  0.56 : 57.9263410729
# Overall on everything:0.22  ,  0.55 : 57.9663730985
# Overall on everything:0.22  ,  0.54 : 58.1665332266
# Overall on everything:0.22  ,  0.53 : 58.0864691753
# Overall on everything:0.22  ,  0.52 : 58.2866293034
# Overall on everything:0.22  ,  0.51 : 58.2866293034
# Overall on everything:0.22  ,  0.5 : 58.4867894315
# Overall on everything:0.22  ,  0.49 : 58.5268214572
# Overall on everything:0.22  ,  0.48 : 58.6869495596
# Overall on everything:0.22  ,  0.47 : 58.7269815853
# Overall on everything:0.22  ,  0.46 : 58.7670136109
# Overall on everything:0.22  ,  0.45 : 58.7269815853
# Overall on everything:0.22  ,  0.44 : 58.7269815853
# Overall on everything:0.22  ,  0.43 : 58.7670136109
# Overall on everything:0.22  ,  0.42 : 58.8470776621
# Overall on everything:0.22  ,  0.41 : 59.0472377902
# Overall on everything:0.22  ,  0.4 : 59.0072057646
# Overall on everything:0.22  ,  0.39 : 59.1273018415
# Overall on everything:0.22  ,  0.38 : 59.287429944
# Overall on everything:0.22  ,  0.37 : 59.0872698159
# Overall on everything:0.22  ,  0.36 : 59.0872698159
# Overall on everything:0.22  ,  0.35 : 59.1273018415
# Overall on everything:0.22  ,  0.34 : 59.4075260208
# Overall on everything:0.22  ,  0.33 : 59.5276220977
# Overall on everything:0.22  ,  0.32 : 59.6477181745
# Overall on everything:0.22  ,  0.31 : 59.5676541233
# Overall on everything:0.22  ,  0.3 : 59.6477181745
# Overall on everything:0.22  ,  0.29 : 59.6076861489
# Overall on everything:0.22  ,  0.28 : 59.6877502002
# Overall on everything:0.22  ,  0.27 : 59.4875900721
# Overall on everything:0.22  ,  0.26 : 59.7277822258
# Overall on everything:0.22  ,  0.25 : 59.7678142514
# Overall on everything:0.22  ,  0.24 : 59.807846277
# Overall on everything:0.22  ,  0.23 : 59.8879103283
# Overall on everything:0.22  ,  0.22 : 59.8478783026
# Overall on everything:0.22  ,  0.21 : 59.9679743795
# Overall on everything:0.22  ,  0.2 : 60.0880704564
# Overall on everything:0.22  ,  0.19 : 60.3282626101
# Overall on everything:0.22  ,  0.18 : 60.4083266613
# Overall on everything:0.22  ,  0.17 : 60.6485188151
# Overall on everything:0.22  ,  0.16 : 60.4883907126
# Overall on everything:0.22  ,  0.15 : 60.4083266613
# Overall on everything:0.22  ,  0.14 : 60.4483586869
# Overall on everything:0.22  ,  0.13 : 60.3682946357
# Overall on everything:0.22  ,  0.12 : 60.4883907126
# Overall on everything:0.22  ,  0.11 : 60.5284227382
# Overall on everything:0.23  ,  0.62 : 57.2457966373
# Overall on everything:0.23  ,  0.61 : 57.3258606886
# Overall on everything:0.23  ,  0.6 : 57.2457966373
# Overall on everything:0.23  ,  0.59 : 57.3658927142
# Overall on everything:0.23  ,  0.58 : 57.5260208167
# Overall on everything:0.23  ,  0.57 : 57.6861489191
# Overall on everything:0.23  ,  0.56 : 57.806244996
# Overall on everything:0.23  ,  0.55 : 57.9663730985
# Overall on everything:0.23  ,  0.54 : 58.0864691753
# Overall on everything:0.23  ,  0.53 : 58.126501201
# Overall on everything:0.23  ,  0.52 : 58.126501201
# Overall on everything:0.23  ,  0.51 : 58.126501201
# Overall on everything:0.23  ,  0.5 : 58.3666933547
# Overall on everything:0.23  ,  0.49 : 58.4867894315
# Overall on everything:0.23  ,  0.48 : 58.6869495596
# Overall on everything:0.23  ,  0.47 : 58.7269815853
# Overall on everything:0.23  ,  0.46 : 58.646917534
# Overall on everything:0.23  ,  0.45 : 58.646917534
# Overall on everything:0.23  ,  0.44 : 58.8470776621
# Overall on everything:0.23  ,  0.43 : 58.8871096878
# Overall on everything:0.23  ,  0.42 : 58.8871096878
# Overall on everything:0.23  ,  0.41 : 58.967173739
# Overall on everything:0.23  ,  0.4 : 59.0072057646
# Overall on everything:0.23  ,  0.39 : 59.1673338671
# Overall on everything:0.23  ,  0.38 : 59.2073658927
# Overall on everything:0.23  ,  0.37 : 59.287429944
# Overall on everything:0.23  ,  0.36 : 59.1273018415
# Overall on everything:0.23  ,  0.35 : 59.1673338671
# Overall on everything:0.23  ,  0.34 : 59.3274619696
# Overall on everything:0.23  ,  0.33 : 59.6477181745
# Overall on everything:0.23  ,  0.32 : 59.6076861489
# Overall on everything:0.23  ,  0.31 : 59.5676541233
# Overall on everything:0.23  ,  0.3 : 59.6477181745
# Overall on everything:0.23  ,  0.29 : 59.6477181745
# Overall on everything:0.23  ,  0.28 : 59.6877502002
# Overall on everything:0.23  ,  0.27 : 59.5676541233
# Overall on everything:0.23  ,  0.26 : 59.6877502002
# Overall on everything:0.23  ,  0.25 : 59.8478783026
# Overall on everything:0.23  ,  0.24 : 59.7678142514
# Overall on everything:0.23  ,  0.23 : 59.8879103283
# Overall on everything:0.23  ,  0.22 : 59.8478783026
# Overall on everything:0.23  ,  0.21 : 59.9279423539
# Overall on everything:0.23  ,  0.2 : 59.9679743795
# Overall on everything:0.23  ,  0.19 : 60.1681345076
# Overall on everything:0.23  ,  0.18 : 60.4083266613
# Overall on everything:0.23  ,  0.17 : 60.4883907126
# Overall on everything:0.23  ,  0.16 : 60.6485188151
# Overall on everything:0.23  ,  0.15 : 60.5284227382
# Overall on everything:0.23  ,  0.14 : 60.5284227382
# Overall on everything:0.23  ,  0.13 : 60.4883907126
# Overall on everything:0.23  ,  0.12 : 60.4883907126
# Overall on everything:0.23  ,  0.11 : 60.4483586869
# Overall on everything:0.24  ,  0.61 : 57.4059247398
# Overall on everything:0.24  ,  0.6 : 57.4059247398
# Overall on everything:0.24  ,  0.59 : 57.485988791
# Overall on everything:0.24  ,  0.58 : 57.5660528423
# Overall on everything:0.24  ,  0.57 : 57.6461168935
# Overall on everything:0.24  ,  0.56 : 57.8462770216
# Overall on everything:0.24  ,  0.55 : 57.9263410729
# Overall on everything:0.24  ,  0.54 : 58.126501201
# Overall on everything:0.24  ,  0.53 : 58.0464371497
# Overall on everything:0.24  ,  0.52 : 58.126501201
# Overall on everything:0.24  ,  0.51 : 58.1665332266
# Overall on everything:0.24  ,  0.5 : 58.3666933547
# Overall on everything:0.24  ,  0.49 : 58.4867894315
# Overall on everything:0.24  ,  0.48 : 58.6068855084
# Overall on everything:0.24  ,  0.47 : 58.7269815853
# Overall on everything:0.24  ,  0.46 : 58.6068855084
# Overall on everything:0.24  ,  0.45 : 58.7269815853
# Overall on everything:0.24  ,  0.44 : 58.7670136109
# Overall on everything:0.24  ,  0.43 : 58.9271417134
# Overall on everything:0.24  ,  0.42 : 58.967173739
# Overall on everything:0.24  ,  0.41 : 59.1273018415
# Overall on everything:0.24  ,  0.4 : 59.1273018415
# Overall on everything:0.24  ,  0.39 : 59.0872698159
# Overall on everything:0.24  ,  0.38 : 59.2073658927
# Overall on everything:0.24  ,  0.37 : 59.287429944
# Overall on everything:0.24  ,  0.36 : 59.287429944
# Overall on everything:0.24  ,  0.35 : 59.4075260208
# Overall on everything:0.24  ,  0.34 : 59.4875900721
# Overall on everything:0.24  ,  0.33 : 59.6076861489
# Overall on everything:0.24  ,  0.32 : 59.6877502002
# Overall on everything:0.24  ,  0.31 : 59.7277822258
# Overall on everything:0.24  ,  0.3 : 59.6877502002
# Overall on everything:0.24  ,  0.29 : 59.6877502002
# Overall on everything:0.24  ,  0.28 : 59.7678142514
# Overall on everything:0.24  ,  0.27 : 59.7678142514
# Overall on everything:0.24  ,  0.26 : 59.7277822258
# Overall on everything:0.24  ,  0.25 : 59.807846277
# Overall on everything:0.24  ,  0.24 : 59.807846277
# Overall on everything:0.24  ,  0.23 : 59.7678142514
# Overall on everything:0.24  ,  0.22 : 59.7277822258
# Overall on everything:0.24  ,  0.21 : 59.8879103283
# Overall on everything:0.24  ,  0.2 : 60.0080064051
# Overall on everything:0.24  ,  0.19 : 60.128102482
# Overall on everything:0.24  ,  0.18 : 60.4083266613
# Overall on everything:0.24  ,  0.17 : 60.4883907126
# Overall on everything:0.24  ,  0.16 : 60.6485188151
# Overall on everything:0.24  ,  0.15 : 60.7285828663
# Overall on everything:0.24  ,  0.14 : 60.6485188151
# Overall on everything:0.24  ,  0.13 : 60.6084867894
# Overall on everything:0.24  ,  0.12 : 60.4883907126
# Overall on everything:0.24  ,  0.11 : 60.4483586869
# Overall on everything:0.25  ,  0.6 : 57.4459567654
# Overall on everything:0.25  ,  0.59 : 57.5660528423
# Overall on everything:0.25  ,  0.58 : 57.6461168935
# Overall on everything:0.25  ,  0.57 : 57.6060848679
# Overall on everything:0.25  ,  0.56 : 57.8462770216
# Overall on everything:0.25  ,  0.55 : 57.8863090472
# Overall on everything:0.25  ,  0.54 : 58.126501201
# Overall on everything:0.25  ,  0.53 : 58.0064051241
# Overall on everything:0.25  ,  0.52 : 58.0864691753
# Overall on everything:0.25  ,  0.51 : 58.1665332266
# Overall on everything:0.25  ,  0.5 : 58.2065652522
# Overall on everything:0.25  ,  0.49 : 58.3666933547
# Overall on everything:0.25  ,  0.48 : 58.646917534
# Overall on everything:0.25  ,  0.47 : 58.7269815853
# Overall on everything:0.25  ,  0.46 : 58.6869495596
# Overall on everything:0.25  ,  0.45 : 58.7269815853
# Overall on everything:0.25  ,  0.44 : 58.7670136109
# Overall on everything:0.25  ,  0.43 : 58.967173739
# Overall on everything:0.25  ,  0.42 : 59.0072057646
# Overall on everything:0.25  ,  0.41 : 59.2473979183
# Overall on everything:0.25  ,  0.4 : 59.2473979183
# Overall on everything:0.25  ,  0.39 : 59.2073658927
# Overall on everything:0.25  ,  0.38 : 59.3274619696
# Overall on everything:0.25  ,  0.37 : 59.5276220977
# Overall on everything:0.25  ,  0.36 : 59.4075260208
# Overall on everything:0.25  ,  0.35 : 59.4875900721
# Overall on everything:0.25  ,  0.34 : 59.5676541233
# Overall on everything:0.25  ,  0.33 : 59.6877502002
# Overall on everything:0.25  ,  0.32 : 59.7678142514
# Overall on everything:0.25  ,  0.31 : 59.7277822258
# Overall on everything:0.25  ,  0.3 : 59.7678142514
# Overall on everything:0.25  ,  0.29 : 59.7277822258
# Overall on everything:0.25  ,  0.28 : 60.0080064051
# Overall on everything:0.25  ,  0.27 : 59.807846277
# Overall on everything:0.25  ,  0.26 : 59.7678142514
# Overall on everything:0.25  ,  0.25 : 59.6877502002
# Overall on everything:0.25  ,  0.24 : 59.7277822258
# Overall on everything:0.25  ,  0.23 : 59.7678142514
# Overall on everything:0.25  ,  0.22 : 59.7678142514
# Overall on everything:0.25  ,  0.21 : 59.7277822258
# Overall on everything:0.25  ,  0.2 : 60.0080064051
# Overall on everything:0.25  ,  0.19 : 60.0880704564
# Overall on everything:0.25  ,  0.18 : 60.2882305845
# Overall on everything:0.25  ,  0.17 : 60.4483586869
# Overall on everything:0.25  ,  0.16 : 60.5684547638
# Overall on everything:0.25  ,  0.15 : 60.7285828663
# Overall on everything:0.25  ,  0.14 : 60.6885508407
# Overall on everything:0.25  ,  0.13 : 60.6485188151
# Overall on everything:0.25  ,  0.12 : 60.6084867894
# Overall on everything:0.25  ,  0.11 : 60.5284227382
# Overall on everything:0.26  ,  0.59 : 57.5260208167
# Overall on everything:0.26  ,  0.58 : 57.7261809448
# Overall on everything:0.26  ,  0.57 : 57.8863090472
# Overall on everything:0.26  ,  0.56 : 57.8462770216
# Overall on everything:0.26  ,  0.55 : 58.0064051241
# Overall on everything:0.26  ,  0.54 : 58.0864691753
# Overall on everything:0.26  ,  0.53 : 58.0864691753
# Overall on everything:0.26  ,  0.52 : 58.1665332266
# ...
# Overall on everything:0.5  ,  0.18 : 59.9679743795
# Overall on everything:0.5  ,  0.17 : 60.2081665332
# Overall on everything:0.5  ,  0.16 : 60.2081665332
# Overall on everything:0.5  ,  0.15 : 60.2882305845
# Overall on everything:0.5  ,  0.14 : 60.2882305845
# Overall on everything:0.5  ,  0.13 : 60.1681345076
# Overall on everything:0.5  ,  0.12 : 60.3282626101
# Overall on everything:0.5  ,  0.11 : 60.5684547638
# Overall on everything:0.51  ,  0.34 : 59.5276220977
# Overall on everything:0.51  ,  0.33 : 59.6076861489
# Overall on everything:0.51  ,  0.32 : 59.7678142514
# Overall on everything:0.51  ,  0.31 : 59.8478783026
# Overall on everything:0.51  ,  0.3 : 60.0080064051
# Overall on everything:0.51  ,  0.29 : 60.0080064051
# Overall on everything:0.51  ,  0.28 : 60.0880704564
# Overall on everything:0.51  ,  0.27 : 60.0880704564
# Overall on everything:0.51  ,  0.26 : 59.9679743795
# Overall on everything:0.51  ,  0.25 : 59.8478783026
# Overall on everything:0.51  ,  0.24 : 59.7678142514
# Overall on everything:0.51  ,  0.23 : 59.6477181745
# Overall on everything:0.51  ,  0.22 : 59.6076861489
# Overall on everything:0.51  ,  0.21 : 59.807846277
# Overall on everything:0.51  ,  0.2 : 59.8478783026
# Overall on everything:0.51  ,  0.19 : 59.9679743795
# Overall on everything:0.51  ,  0.18 : 59.8879103283
# Overall on everything:0.51  ,  0.17 : 60.0880704564
# Overall on everything:0.51  ,  0.16 : 60.128102482
# Overall on everything:0.51  ,  0.15 : 60.1681345076
# Overall on everything:0.51  ,  0.14 : 60.2081665332
# Overall on everything:0.51  ,  0.13 : 60.2882305845
# Overall on everything:0.51  ,  0.12 : 60.3282626101
# Overall on everything:0.51  ,  0.11 : 60.3682946357
# Overall on everything:0.52  ,  0.33 : 59.6477181745
# Overall on everything:0.52  ,  0.32 : 59.7678142514
# Overall on everything:0.52  ,  0.31 : 59.7277822258
# Overall on everything:0.52  ,  0.3 : 59.9279423539
# Overall on everything:0.52  ,  0.29 : 60.0080064051
# Overall on everything:0.52  ,  0.28 : 60.0880704564
# Overall on everything:0.52  ,  0.27 : 60.128102482
# Overall on everything:0.52  ,  0.26 : 60.0080064051
# Overall on everything:0.52  ,  0.25 : 59.7678142514
# Overall on everything:0.52  ,  0.24 : 59.7277822258
# Overall on everything:0.52  ,  0.23 : 59.5676541233
# Overall on everything:0.52  ,  0.22 : 59.5676541233
# Overall on everything:0.52  ,  0.21 : 59.6477181745
# Overall on everything:0.52  ,  0.2 : 59.8478783026
# Overall on everything:0.52  ,  0.19 : 59.9279423539
# Overall on everything:0.52  ,  0.18 : 59.8879103283
# Overall on everything:0.52  ,  0.17 : 59.9279423539
# Overall on everything:0.52  ,  0.16 : 60.0080064051
# Overall on everything:0.52  ,  0.15 : 60.0880704564
# Overall on everything:0.52  ,  0.14 : 60.128102482
# Overall on everything:0.52  ,  0.13 : 60.2081665332
# Overall on everything:0.52  ,  0.12 : 60.4083266613
# Overall on everything:0.52  ,  0.11 : 60.3682946357
# Overall on everything:0.53  ,  0.32 : 59.7277822258
# Overall on everything:0.53  ,  0.31 : 59.807846277
# Overall on everything:0.53  ,  0.3 : 60.0080064051
# Overall on everything:0.53  ,  0.29 : 59.9279423539
# Overall on everything:0.53  ,  0.28 : 60.128102482
# Overall on everything:0.53  ,  0.27 : 60.0080064051
# Overall on everything:0.53  ,  0.26 : 60.0480384307
# Overall on everything:0.53  ,  0.25 : 59.7277822258
# Overall on everything:0.53  ,  0.24 : 59.6477181745
# Overall on everything:0.53  ,  0.23 : 59.6477181745
# Overall on everything:0.53  ,  0.22 : 59.5276220977
# Overall on everything:0.53  ,  0.21 : 59.5676541233
# Overall on everything:0.53  ,  0.2 : 59.6076861489
# Overall on everything:0.53  ,  0.19 : 59.8478783026
# Overall on everything:0.53  ,  0.18 : 59.7678142514
# Overall on everything:0.53  ,  0.17 : 59.8478783026
# Overall on everything:0.53  ,  0.16 : 59.9679743795
# Overall on everything:0.53  ,  0.15 : 60.0480384307
# Overall on everything:0.53  ,  0.14 : 60.0480384307
# Overall on everything:0.53  ,  0.13 : 60.1681345076
# Overall on everything:0.53  ,  0.12 : 60.3282626101
# Overall on everything:0.53  ,  0.11 : 60.3282626101
# Overall on everything:0.54  ,  0.31 : 59.7678142514
# Overall on everything:0.54  ,  0.3 : 59.807846277
# Overall on everything:0.54  ,  0.29 : 59.8879103283
# Overall on everything:0.54  ,  0.28 : 59.8879103283
# Overall on everything:0.54  ,  0.27 : 60.0080064051
# Overall on everything:0.54  ,  0.26 : 60.0080064051
# Overall on everything:0.54  ,  0.25 : 59.8478783026
# Overall on everything:0.54  ,  0.24 : 59.7277822258
# Overall on everything:0.54  ,  0.23 : 59.6877502002
# Overall on everything:0.54  ,  0.22 : 59.5676541233
# Overall on everything:0.54  ,  0.21 : 59.5276220977
# Overall on everything:0.54  ,  0.2 : 59.6477181745
# Overall on everything:0.54  ,  0.19 : 59.5676541233
# Overall on everything:0.54  ,  0.18 : 59.7678142514
# Overall on everything:0.54  ,  0.17 : 59.807846277
# Overall on everything:0.54  ,  0.16 : 59.8879103283
# Overall on everything:0.54  ,  0.15 : 59.9279423539
# Overall on everything:0.54  ,  0.14 : 60.0080064051
# Overall on everything:0.54  ,  0.13 : 60.0880704564
# Overall on everything:0.54  ,  0.12 : 60.3282626101
# Overall on everything:0.54  ,  0.11 : 60.4083266613
# Overall on everything:0.55  ,  0.3 : 59.6877502002
# Overall on everything:0.55  ,  0.29 : 59.7678142514
# Overall on everything:0.55  ,  0.28 : 59.8478783026
# Overall on everything:0.55  ,  0.27 : 59.9679743795
# Overall on everything:0.55  ,  0.26 : 59.8879103283
# Overall on everything:0.55  ,  0.25 : 59.9279423539
# Overall on everything:0.55  ,  0.24 : 59.807846277
# Overall on everything:0.55  ,  0.23 : 59.807846277
# Overall on everything:0.55  ,  0.22 : 59.5676541233
# Overall on everything:0.55  ,  0.21 : 59.5676541233
# Overall on everything:0.55  ,  0.2 : 59.5676541233
# Overall on everything:0.55  ,  0.19 : 59.6477181745
# Overall on everything:0.55  ,  0.18 : 59.7277822258
# Overall on everything:0.55  ,  0.17 : 59.7678142514
# Overall on everything:0.55  ,  0.16 : 59.7277822258
# Overall on everything:0.55  ,  0.15 : 59.8879103283
# Overall on everything:0.55  ,  0.14 : 59.9679743795
# Overall on everything:0.55  ,  0.13 : 60.128102482
# Overall on everything:0.55  ,  0.12 : 60.2882305845
# Overall on everything:0.55  ,  0.11 : 60.3682946357
# Overall on everything:0.56  ,  0.29 : 59.6477181745
# Overall on everything:0.56  ,  0.28 : 59.8879103283
# Overall on everything:0.56  ,  0.27 : 60.0080064051
# Overall on everything:0.56  ,  0.26 : 59.8879103283
# Overall on everything:0.56  ,  0.25 : 59.9279423539
# Overall on everything:0.56  ,  0.24 : 59.8879103283
# Overall on everything:0.56  ,  0.23 : 59.7678142514
# Overall on everything:0.56  ,  0.22 : 59.7277822258
# Overall on everything:0.56  ,  0.21 : 59.5676541233
# Overall on everything:0.56  ,  0.2 : 59.5676541233
# Overall on everything:0.56  ,  0.19 : 59.6877502002
# Overall on everything:0.56  ,  0.18 : 59.7277822258
# Overall on everything:0.56  ,  0.17 : 59.7277822258
# Overall on everything:0.56  ,  0.16 : 59.807846277
# Overall on everything:0.56  ,  0.15 : 60.0080064051
# Overall on everything:0.56  ,  0.14 : 60.0880704564
# Overall on everything:0.56  ,  0.13 : 60.1681345076
# Overall on everything:0.56  ,  0.12 : 60.2882305845
# Overall on everything:0.56  ,  0.11 : 60.3282626101
# Overall on everything:0.57  ,  0.28 : 59.807846277
# Overall on everything:0.57  ,  0.27 : 59.9279423539
# Overall on everything:0.57  ,  0.26 : 59.9279423539
# Overall on everything:0.57  ,  0.25 : 59.807846277
# Overall on everything:0.57  ,  0.24 : 59.807846277
# Overall on everything:0.57  ,  0.23 : 59.7678142514
# Overall on everything:0.57  ,  0.22 : 59.6877502002
# Overall on everything:0.57  ,  0.21 : 59.6477181745
# Overall on everything:0.57  ,  0.2 : 59.6477181745
# Overall on everything:0.57  ,  0.19 : 59.6877502002
# Overall on everything:0.57  ,  0.18 : 59.6877502002
# Overall on everything:0.57  ,  0.17 : 59.7678142514
# Overall on everything:0.57  ,  0.16 : 59.807846277
# Overall on everything:0.57  ,  0.15 : 59.9279423539
# Overall on everything:0.57  ,  0.14 : 60.0480384307
# Overall on everything:0.57  ,  0.13 : 60.0480384307
# Overall on everything:0.57  ,  0.12 : 60.1681345076
# Overall on everything:0.57  ,  0.11 : 60.3282626101
# Overall on everything:0.58  ,  0.27 : 59.8478783026
# Overall on everything:0.58  ,  0.26 : 59.8478783026
# Overall on everything:0.58  ,  0.25 : 59.7678142514
# Overall on everything:0.58  ,  0.24 : 59.7678142514
# Overall on everything:0.58  ,  0.23 : 59.6877502002
# Overall on everything:0.58  ,  0.22 : 59.7277822258
# Overall on everything:0.58  ,  0.21 : 59.6877502002
# Overall on everything:0.58  ,  0.2 : 59.6877502002
# Overall on everything:0.58  ,  0.19 : 59.8879103283
# Overall on everything:0.58  ,  0.18 : 59.8879103283
# Overall on everything:0.58  ,  0.17 : 60.0080064051
# Overall on everything:0.58  ,  0.16 : 59.807846277
# Overall on everything:0.58  ,  0.15 : 59.8478783026
# Overall on everything:0.58  ,  0.14 : 59.9679743795
# Overall on everything:0.58  ,  0.13 : 59.9679743795
# Overall on everything:0.58  ,  0.12 : 60.0880704564
# Overall on everything:0.58  ,  0.11 : 60.2481985588
# Overall on everything:0.59  ,  0.26 : 59.7678142514
# Overall on everything:0.59  ,  0.25 : 59.6877502002
# Overall on everything:0.59  ,  0.24 : 59.6877502002
# Overall on everything:0.59  ,  0.23 : 59.6877502002
# Overall on everything:0.59  ,  0.22 : 59.807846277
# Overall on everything:0.59  ,  0.21 : 59.8478783026
# Overall on everything:0.59  ,  0.2 : 59.8478783026
# Overall on everything:0.59  ,  0.19 : 59.8879103283
# Overall on everything:0.59  ,  0.18 : 59.8478783026
# Overall on everything:0.59  ,  0.17 : 60.0080064051
# Overall on everything:0.59  ,  0.16 : 59.8478783026
# Overall on everything:0.59  ,  0.15 : 59.8478783026
# Overall on everything:0.59  ,  0.14 : 59.9279423539
# Overall on everything:0.59  ,  0.13 : 59.9679743795
# Overall on everything:0.59  ,  0.12 : 60.0480384307
# Overall on everything:0.59  ,  0.11 : 60.2081665332
# Overall on everything:0.6  ,  0.25 : 59.7277822258
# Overall on everything:0.6  ,  0.24 : 59.807846277
# Overall on everything:0.6  ,  0.23 : 59.7277822258
# Overall on everything:0.6  ,  0.22 : 59.9279423539
# Overall on everything:0.6  ,  0.21 : 59.8478783026
# Overall on everything:0.6  ,  0.2 : 59.807846277
# Overall on everything:0.6  ,  0.19 : 59.8478783026
# Overall on everything:0.6  ,  0.18 : 59.9279423539
# Overall on everything:0.6  ,  0.17 : 60.0080064051
# Overall on everything:0.6  ,  0.16 : 59.9679743795
# Overall on everything:0.6  ,  0.15 : 59.9279423539
# Overall on everything:0.6  ,  0.14 : 59.9279423539
# Overall on everything:0.6  ,  0.13 : 59.9279423539
# Overall on everything:0.6  ,  0.12 : 60.0080064051
# Overall on everything:0.6  ,  0.11 : 60.3282626101
# Overall on everything:0.61  ,  0.24 : 59.8478783026
# Overall on everything:0.61  ,  0.23 : 59.8478783026
# Overall on everything:0.61  ,  0.22 : 59.807846277
# Overall on everything:0.61  ,  0.21 : 59.9279423539
# Overall on everything:0.61  ,  0.2 : 59.8879103283
# Overall on everything:0.61  ,  0.19 : 59.7678142514
# Overall on everything:0.61  ,  0.18 : 59.8879103283
# Overall on everything:0.61  ,  0.17 : 60.0080064051
# Overall on everything:0.61  ,  0.16 : 60.0480384307
# Overall on everything:0.61  ,  0.15 : 60.0880704564
# Overall on everything:0.61  ,  0.14 : 59.9679743795
# Overall on everything:0.61  ,  0.13 : 59.9679743795
# Overall on everything:0.61  ,  0.12 : 59.8879103283
# Overall on everything:0.61  ,  0.11 : 60.2481985588
# Overall on everything:0.62  ,  0.23 : 59.8879103283
# Overall on everything:0.62  ,  0.22 : 59.807846277
# Overall on everything:0.62  ,  0.21 : 59.8478783026
# Overall on everything:0.62  ,  0.2 : 59.9279423539
# Overall on everything:0.62  ,  0.19 : 59.8879103283
# Overall on everything:0.62  ,  0.18 : 59.9679743795
# Overall on everything:0.62  ,  0.17 : 59.8879103283
# Overall on everything:0.62  ,  0.16 : 60.0080064051
# Overall on everything:0.62  ,  0.15 : 60.2882305845
# Overall on everything:0.62  ,  0.14 : 60.2081665332
# Overall on everything:0.62  ,  0.13 : 60.128102482
# Overall on everything:0.62  ,  0.12 : 60.0480384307
# Overall on everything:0.62  ,  0.11 : 60.0880704564
# Overall on everything:0.63  ,  0.22 : 59.807846277
# Overall on everything:0.63  ,  0.21 : 59.7678142514
# Overall on everything:0.63  ,  0.2 : 59.7678142514
# Overall on everything:0.63  ,  0.19 : 59.9679743795
# Overall on everything:0.63  ,  0.18 : 59.9279423539
# Overall on everything:0.63  ,  0.17 : 60.0080064051
# Overall on everything:0.63  ,  0.16 : 59.9279423539
# Overall on everything:0.63  ,  0.15 : 60.1681345076
# Overall on everything:0.63  ,  0.14 : 60.2882305845
# Overall on everything:0.63  ,  0.13 : 60.2882305845
# Overall on everything:0.63  ,  0.12 : 60.2481985588
# Overall on everything:0.63  ,  0.11 : 60.2081665332
# Overall on everything:0.64  ,  0.21 : 59.7678142514
# Overall on everything:0.64  ,  0.2 : 59.807846277
# Overall on everything:0.64  ,  0.19 : 59.807846277
# Overall on everything:0.64  ,  0.18 : 60.0080064051
# Overall on everything:0.64  ,  0.17 : 59.9279423539
# Overall on everything:0.64  ,  0.16 : 60.0880704564
# Overall on everything:0.64  ,  0.15 : 60.1681345076
# Overall on everything:0.64  ,  0.14 : 60.3282626101
# Overall on everything:0.64  ,  0.13 : 60.2882305845
# Overall on everything:0.64  ,  0.12 : 60.128102482
# Overall on everything:0.64  ,  0.11 : 60.128102482
# Overall on everything:0.65  ,  0.2 : 59.7277822258
# Overall on everything:0.65  ,  0.19 : 59.7678142514
# Overall on everything:0.65  ,  0.18 : 60.0080064051
# Overall on everything:0.65  ,  0.17 : 60.128102482
# Overall on everything:0.65  ,  0.16 : 60.1681345076
# Overall on everything:0.65  ,  0.15 : 60.1681345076
# Overall on everything:0.65  ,  0.14 : 60.3682946357
# Overall on everything:0.65  ,  0.13 : 60.3282626101
# Overall on everything:0.65  ,  0.12 : 60.2882305845
# Overall on everything:0.65  ,  0.11 : 60.0880704564
# Overall on everything:0.66  ,  0.19 : 59.7277822258
# Overall on everything:0.66  ,  0.18 : 59.9279423539
# Overall on everything:0.66  ,  0.17 : 60.0880704564
# Overall on everything:0.66  ,  0.16 : 60.128102482
# Overall on everything:0.66  ,  0.15 : 60.0880704564
# Overall on everything:0.66  ,  0.14 : 60.4083266613
# Overall on everything:0.66  ,  0.13 : 60.4083266613
# Overall on everything:0.66  ,  0.12 : 60.3682946357
# Overall on everything:0.66  ,  0.11 : 60.128102482
# Overall on everything:0.67  ,  0.18 : 59.8879103283
# Overall on everything:0.67  ,  0.17 : 60.0080064051
# Overall on everything:0.67  ,  0.16 : 60.0480384307
# Overall on everything:0.67  ,  0.15 : 60.0480384307
# Overall on everything:0.67  ,  0.14 : 60.2481985588
# Overall on everything:0.67  ,  0.13 : 60.3282626101
# Overall on everything:0.67  ,  0.12 : 60.3682946357
# Overall on everything:0.67  ,  0.11 : 60.1681345076
# Overall on everything:0.68  ,  0.17 : 59.9679743795
# Overall on everything:0.68  ,  0.16 : 59.9679743795
# Overall on everything:0.68  ,  0.15 : 60.0480384307
# Overall on everything:0.68  ,  0.14 : 60.2481985588
# Overall on everything:0.68  ,  0.13 : 60.2882305845
# Overall on everything:0.68  ,  0.12 : 60.2481985588
# Overall on everything:0.68  ,  0.11 : 60.1681345076
# Overall on everything:0.69  ,  0.16 : 60.0480384307
# Overall on everything:0.69  ,  0.15 : 60.0480384307
# Overall on everything:0.69  ,  0.14 : 60.1681345076
# Overall on everything:0.69  ,  0.13 : 60.2481985588
# Overall on everything:0.69  ,  0.12 : 60.2481985588
# Overall on everything:0.69  ,  0.11 : 60.2081665332
# Overall on everything:0.7  ,  0.15 : 60.0880704564
# Overall on everything:0.7  ,  0.14 : 60.3282626101
# Overall on everything:0.7  ,  0.13 : 60.2481985588
# Overall on everything:0.7  ,  0.12 : 60.2481985588
# Overall on everything:0.7  ,  0.11 : 60.1681345076
# Overall on everything:0.71  ,  0.14 : 60.2481985588
# Overall on everything:0.71  ,  0.13 : 60.3282626101
# Overall on everything:0.71  ,  0.12 : 60.2481985588
# Overall on everything:0.71  ,  0.11 : 60.2882305845
# Overall on everything:0.72  ,  0.13 : 60.2481985588
# Overall on everything:0.72  ,  0.12 : 60.2481985588
# Overall on everything:0.72  ,  0.11 : 60.2481985588
# Overall on everything:0.73  ,  0.12 : 60.2882305845
# Overall on everything:0.73  ,  0.11 : 60.2481985588
# Overall on everything:0.74  ,  0.11 : 60.2081665332
# max val: 60.7686148919

# %%
def evaluateY(Y, YHat):
    total = len(YHat)
    count = 0
    for i in range(1, total-1):
        if (YHat[i] - YHat[i-1]) * (Y[i] - Y[i-1]) > 0:
            count += 1
    return (count * 100.0 / total)

# %%
dataframe_gene = pandas.read_csv('orderedYHat_Part3+Nasdaq89+Verified', usecols="0")

geneYHat = dataframe_gene.values

geneYHat = geneYHat.ravel()
def evaluateY(Y, YHat):
    total = len(YHat)
#     print(len(Y))
#     print(total)
    count = 0
    for i in range(1, total-1):
        if (YHat[i] - YHat[i-1]) * (Y[i] - Y[i-1]) > 0:
            count += 1
    return (count * 100.0 / total)

print len(geneYHat)
plt.figure(figsize=(40,20))

plt.plot(orderedY)
plt.plot(geneYHat, c = 'r')
plt.show()
YLen = len(geneYHat)
def weight_tweaking(w1, w2, w3):
    man_YHat = []
    for i in range(YLen):
        x = (orderedYHat_LSTM[i]*w1 + orderedYHat_CONV[i]*w2 + orderedYHat_DENSE[i]*(1 - w1 - w2-w3) + geneYHat[i]*w3)
        man_YHat.append(x)
    return man_YHat
# Out:
# 1248

# %%
gene_man = weight_tweaking(.8, .1, .1)
print('Overall on everything: {}'.format(evaluateY(orderedY, gene_man)))
# Out:
# Overall on everything: 52.0833333333

# %%
x = [[1], [2], [3]]
x = np.array(x)
x = x.ravel()
x = x.ravel()
print(x.shape)
print(x)
# Out:
# (3,)
# [1 2 3]

# %%
print geneYHat
# Out:
# [ 17.01721382  16.72304535  16.43849564 ...,  49.36474228  49.31121445
#   49.5650444 ]
